# %%
import nltk, re, pprint
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('C:')
nltk.download ('stopwords')
import random
from random import randrange
import collections
from nltk.tokenize import TweetTokenizer, RegexpTokenizer
from nltk.corpus import stopwords
import string
import itertools
import os
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import tweepy
import time
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\merse\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\merse\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Error loading C:: Package 'C:' not found in index
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\merse\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
class Node(object):
    def __init__(self, data):
        self.data = data
        self.children = []

    def add_child(self, obj):
        self.children.append(obj)

# %%
n = Node(5)
p = Node(6)
q = Node(7)
n.add_child(p)
n.add_child(q)
n.children

# %%
 for c in n.children:
        print (c.data)

# %%
sent1 = ['Call', 'me', 'Ishmael', '.']

# %%
f = open('C:\\Users\\merse\\Desktop\\Commonsensical\\Projects\\May 2021\\Twitter Bot, the revolutionary poet\\4. Development\\Corpus\\test.txt')
raw = f.read()

# %%
raw

# %%
tknzr = TweetTokenizer()
tknzr.tokenize(raw)

# %%
tknzr = TweetTokenizer()
s0 = "This is a cooool #dummysmiley: :-) :-P <3 and some arrows < > -> <--"
text = tknzr.tokenize(s0)

# %%
text = nltk.word_tokenize("And now for something completely different")
analysed_text =nltk.pos_tag(text)
analysed_text

# %%
f = open('C:\\Users\\merse\\Desktop\\Commonsensical\\Projects\\May 2021\\Twitter Bot, the revolutionary poet\\4. Development\\Corpus\\test.txt')
raw = f.read()

text2 = nltk.word_tokenize(raw)
analysed_text2 =nltk.pos_tag(text2)
print(raw)
print("-------")
print(analysed_text2)

# %%
def ie_preprocess(document):
    sentences = nltk.sent_tokenize(document)
    sentences = [nltk.word_tokenize(sent) for sent in sentences]
    sentences = [nltk.pos_tag(sent) for sent in sentences]

# %%
groucho_grammar = nltk.CFG.fromstring("""
    S -> NP VP
    PP -> P NP
    NP -> Det N | Det N PP | 'I'
    VP -> V NP | VP PP
    Det -> 'an' | 'my'
    N -> 'elephant' | 'pajamas'
    V -> 'shot'
    P -> 'in'
    """)

# %%
sent = ['I', 'shot', 'an', 'elephant', 'in', 'my', 'pajamas']
parser = nltk.ChartParser(groucho_grammar)
for tree in parser.parse(sent):
    print(tree)

# %%
grammar1 = nltk.CFG.fromstring("""
  S  -> NP VP
  NP -> Det Nom | PropN | 'Mary' | 'Bob'
  Nom -> Adj Nom | N
  VP -> V Adj | V NP | V S | V NP PP
  PP -> P NP
  PropN -> 'Buster' | 'Chatterer' | 'Joe' 
  Det -> 'the' | 'a'
  N -> 'bear' | 'squirrel' | 'tree' | 'fish' | 'log'
  Adj  -> 'angry' | 'frightened' |  'little' | 'tall'
  V ->  'chased'  | 'saw' | 'said' | 'thought' | 'was' | 'put'
  P -> 'on'
  """)


rd_parser = nltk.RecursiveDescentParser(grammar1)
sent = "Mary saw Bob".split()
rd_parser = nltk.RecursiveDescentParser(grammar1)
for tree in rd_parser.parse(sent):
    print(tree)

# %%
grammar1 = nltk.CFG.fromstring("""
  S  -> NP VP
  NP -> Det Nom | PropN | 'Mary' | 'Bob'
  Nom -> Adj Nom | N
  VP -> V Adj | V NP | V S | V NP PP
  PP -> P NP
  PropN -> 'Buster' | 'Chatterer' | 'Joe' 
  Det -> 'the' | 'a'
  N -> 'bear' | 'squirrel' | 'tree' | 'fish' | 'log'
  Adj  -> 'angry' | 'frightened' |  'little' | 'tall'
  V ->  'chased'  | 'saw' | 'said' | 'thought' | 'was' | 'put'
  P -> 'on'
  """)


rd_parser = nltk.RecursiveDescentParser(grammar1)
sent = "Mary saw Bob".split()
rd_parser = nltk.RecursiveDescentParser(grammar1)
for tree in rd_parser.parse(sent):
    print(tree)

# %% [markdown]
# # Test

# %%
sent = "Albert Einstein was born in Ulm, Germany in 1879."
tokens=nltk.word_tokenize(sent)
print(tokens)
['Albert', 'Einstein', 'was', 'born', 'in', 'Ulm', ',', 'Germany', 'in', '1879', '.']
nltk.pos_tag(tokens)


stop_words=set(stopwords.words("english"))
print(stop_words)

# %%
text="""Hello Mr. Smith, how are you doing today? The weather is great, and city is awesome.
The sky is pinkish-blue. You shouldn't eat cardboard"""

tokenized_text=nltk.sent_tokenize(text)
tokens=nltk.word_tokenize(text)
print(tokenized_text)
print(tokens)

# %%
input_text="""Hello Mr. Smith, how are you doing today? The weather is great, and city is awesome.
The sky is pinkish-blue. You shouldn't eat cardboard"""

tokenizer_words = TweetTokenizer()
tokens_sentences = [tokenizer_words.tokenize(t) for t in 
nltk.sent_tokenize(input_text)]
print(tokens_sentences)

# %% [markdown]
# ### with stopwords

# %%
stop_words=set(stopwords.words("english"))

filtered_sent=[]

#for w in tokens_sentences:
#    if w not in stop_words:
#       filtered_sent.append(w)

for sentence in tokens_sentences:
    for word in sentence:
        if word not in stop_words:
            filtered_sent.append(word)


#tokens_sentences[0]
print("Tokenized Sentence:",tokens_sentences)
print("-------------------------------------------------------------------------------------------------")
print("Filterd Sentence:",filtered_sent)

# %% [markdown]
# ## POS Tagging EXAMPLE 1

# %%
input_text="""Hello Mr. Smith, how are you doing today? The weather is great, and city is awesome.
The sky is pinkish-blue. You shouldn't eat cardboard"""

tokenizer_words = TweetTokenizer()
tokens_sentences = [tokenizer_words.tokenize(t) for t in nltk.sent_tokenize(input_text)]
tagged_tokens=[None] * len(tokens_sentences)


for sentence in tokens_sentences:
    tagged_tokens[tokens_sentences.index(sentence)]=nltk.pos_tag(sentence)

# LIST -> LIST -> TUPLE
tagged_tokens

# %% [markdown]
# ## POS Tagging EXAMPLE from txt

# %% [markdown]
# #### Define the tree class

# %%
class Tree(object):
    "Generic tree node."
    def __init__(self, name='root', children=None):
        self.name = name
        self.children = []
        if children is not None:
            for child in children:
                self.add_child(child)
    def __repr__(self):
        return self.name
    def add_child(self, node):
        assert isinstance(node, Tree)
        self.children.append(node)

# EXAMPLES
        
#    *
#   /|\
#  1 2 +
#     / \
#    3   4        
t1 = Tree('*', [Tree('1'),
               Tree('2'),
               Tree('+', [Tree('3'),
                          Tree('4')])])

t1.children[2].children

#    *
#   /|\
#  1 2 +
#     / \
#    3   4 
#       / \
#      5   6

t2 = Tree('*', [Tree('1'),
               Tree('2'),
               Tree('+', [Tree('3'),
                          Tree('4',  [Tree('5'),
                                      Tree('6')])])])

len(t2.children)

# %% [markdown]
# ### 1. Read & Tokenize a text file - EXAMPLE 2

# %%
def read_and_tokenize2(filePath):
    poem_lines=[]
    
    raw = open(filePath)
    input_text = raw.read()
    input_text = input_text.replace("â€™", "'")
    input_text = input_text.replace("â€”", "-")
    
    tknzr = TweetTokenizer()
    tokens=tknzr.tokenize(input_text)

    poem_lines=[]
    sentence=[]
    
    for word in tokens:
        if word != ".":
            pass
            
        else:
            pass

            
    
    return poem_lines


# Example
file_path = 'C:\\Users\\merse\\Desktop\\Commonsensical\\Projects\\May 2021\\Twitter Bot, the revolutionary poet\\4. Development\\Corpus\\test2.txt'
read_and_tokenize2(file_path)

# %%
type(parser)

# %% [markdown]
# ### 4. Create a list of trees based on the tokens

# %%
"""
#    A
#   /|\
#  1 2 B
#     / \
#    3   4 
#       / \
#      5   6

t2 = Tree('A', [Tree('1'),
               Tree('2'),
               Tree('B', [Tree('3'),
                          Tree('4',  [Tree('5'),
                                      Tree('6')])])])"""
class Tree(object):
    "Generic tree node."
    def __init__(self, name='root', children=None):
        self.name = name
        self.children = []
        if children is not None:
            for child in children:
                self.add_child(child)
    def __repr__(self):
        return self.name
    def add_child(self, node):
        assert isinstance(node, Tree)
        self.children.append(node)
        
        
# How many text files in the corpus directory
path, dirs, files = next(os.walk('C:\\Users\\merse\\Desktop\\Commonsensical\\Projects\\May 2021\\Twitter Bot, the revolutionary poet\\4. Development\\Corpus'))
file_count = len(files)

# Create a poem list (empty for now) | essentially one poem for every file
poems = [None] * file_count



# Example
file = 'C:\\Users\\merse\\Desktop\\Commonsensical\\Projects\\May 2021\\Twitter Bot, the revolutionary poet\\4. Development\\Corpus\\test.txt'
raw = open(file)
input_text = raw.read()


tokenized_text = tokenize(input_text)
tokenized_text

# %% [markdown]
# ### ΝΟ - Define a Grammar

# %%
groucho_grammar = nltk.CFG.fromstring("""
    S -> NP VP
    PP -> P NP
    NP -> Det N | Det N PP | 'I'
    VP -> V NP | VP PP
    Det -> 'an' | 'my'
    N -> 'elephant' | 'pajamas'
    V -> 'shot'
    P -> 'in'
    """)

# %%
sent = ['I', 'shot', 'an', 'elephant', 'in', 'my', 'pajamas']
parser = nltk.ChartParser(groucho_grammar)
for tree in parser.parse(sent):
    print(tree)

# %%
for poem in all_file_tokens:
    for sentence in poem:
        print('----------')
        print (sentence)
        print(collections.Counter(word[1] for word in sentence))


#d1 = collections.Counter(k[0] for k in all_file_tokens)

# %% [markdown]
# # -------MAIN CODE

# %% [markdown]
# ### 1. Read & Tokenize a text file - function

# %%
def read_and_tokenize(filePath):
    poem_lines=[]
    input_text = open(filePath, encoding="utf8")
    for line in input_text:
        line = line.lower()
        line_strip=line.strip()
        line_strip = line_strip.replace("â€™", "'")
        line_strip = line_strip.replace("â€”", "-")
        line_strip = line_strip.replace("\'s", "'s")
        tokenizer_words = TweetTokenizer()
        poem_lines.append(tokenizer_words.tokenize(line_strip))        
    return poem_lines


# Example
#file_path = 'C:\\Users\\merse\\Desktop\\Commonsensical\\Projects\\May 2021\\Twitter Bot, the revolutionary poet\\4. Development\\Corpus\\test2.txt'
#read_and_tokenize(file_path)

# %% [markdown]
# ### 2. Analyse the files and tokenize them

# %%
def analyseAndTokenize(directory):
    all_file_tokens=[]
    for file in os.listdir(directory):
        # Tokenize
        tokens_sentences=read_and_tokenize(directory+file)
        tagged_tokens=[None] * len(tokens_sentences)
        # Analyze
        for sentence in tokens_sentences:
            tagged_tokens[tokens_sentences.index(sentence)]=nltk.pos_tag(sentence)

        all_file_tokens.append(tagged_tokens)
    return all_file_tokens


# Example
#directory= 'C:\\Users\\merse\\Desktop\\Commonsensical\\Projects\\May 2021\\Twitter Bot, the revolutionary poet\\4. Development\\Corpus\\'
#analyseAndTokenize(directory)

# %% [markdown]
# ### 3. Create a dictionary including all the grammatical symbols
# ### &  Create a dictionary of sequences of grammatical symbols

# %%
def grammarSymbolsAndSequences(tokens):

    grammar_symbols = {}
    sequences = []

    for poem in tokens:
        #print("------------POEM-------",poem)
        for line in poem:
            # Create a list for the sequence of the specific line
            lineSequence=[]
            #print("------------Line-------",line)
            try:
                for index, word_and_symbol in enumerate(line):
                    key = word_and_symbol[1]
                    value = word_and_symbol[0]
                    # if the key is not in grammar dictionary add it and append it after
                    if key not in grammar_symbols:
                        grammar_symbols[key]=[]
                    if value not in grammar_symbols[key]:
                        grammar_symbols[key].append(value)
                    # Add the value to the sequence list of the line
                    lineSequence.append(key)
                # Add the value to the sequence general list
                sequences.append(lineSequence)
            except:
                #print('error index:',index, word_and_symbol)
                pass
    return grammar_symbols, sequences

# Example
directory= 'C:\\Users\\merse\\Desktop\\Commonsensical\\Projects\\May 2021\\Twitter Bot, the revolutionary poet\\4. Development\\Corpus\\'
all_tokens = analyseAndTokenize(directory)
grammar_symbols, sequences = grammarSymbolsAndSequences(all_tokens)

# %%
#grammar_symbols.find("\\")

def search(myDict, lookup):
    for key, value in myDict.items():
        for v in value:
            if lookup in v:
                return key


search(grammar_symbols, '\\')

# %%
grammar_symbols
# Out:
# {'PRP': ['he',
#   'we',
#   'me',
#   'it',
#   'they',
#   'them',
#   'myself',
#   'him',
#   'you',
#   'us',
#   'themselves',
#   'she',
#   'thyself',
#   'yourself',
#   'itself',
#   'o',
#   "you're",
#   'her',
#   'himself'],
#  'VB': ['ate',
#   'drank',
#   'i',
#   'do',
#   'think',
#   'go',
#   'let',
#   'feel',
#   'have',
#   'refuse',
#   'sleep',
#   'be',
#   'move',
#   "what's",
#   'outrun',
#   'get',
#   'dance',
#   'live',
#   'love',
#   'block',
#   '—',
#   'greet',
#   'leave',
#   'mix',
#   'know',
#   'dwell',
#   'watch',
#   'ask',
#   'swear',
#   'name',
#   'discuss',
#   'askin',
#   'touch',
#   'mad',
#   'report',
#   'callin',
#   'kim',
#   'see',
#   'lower',
#   'straighten',
#   'keep',
#   'play',
#   'believe',
#   'happen',
#   'walk',
#   'say',
#   'buy',
#   'ride',
#   'visit',
#   'flirt',
#   'marry',
#   'run',
#   'follow',
#   'chase',
#   'jump',
#   'anchor',
#   'grow',
#   'challenge',
#   'sever',
#   'torture',
#   'rend',
#   'flee',
#   'gain',
#   '"',
#   'ill',
#   'worship',
#   'speak',
#   'rise',
#   'dazzle',
#   'discard',
#   'become',
#   'abolish',
#   'erase',
#   'dethrone',
#   'cast',
#   'dispel',
#   'escape',
#   'wind',
#   'bindi',
#   '’',
#   'ocean',
#   'come',
#   'die',
#   'honor',
#   'meet',
#   'show',
#   'brave',
#   'deal',
#   'argonne',
#   "youth's",
#   'thee',
#   'win',
#   'kill',
#   'heard',
#   'fuck',
#   'try',
#   'prepare',
#   'blame',
#   'hold',
#   'recognize',
#   'judge',
#   'study',
#   "humb'ly",
#   'muse',
#   'abide',
#   'cute',
#   'built',
#   'suit',
#   'tell',
#   'fall',
#   't',
#   'talk',
#   'make',
#   'look',
#   'sell',
#   'accept',
#   'give',
#   'document',
#   'add',
#   'rest',
#   'take',
#   'bide',
#   'rove',
#   'future',
#   'work',
#   'bent',
#   'hunger',
#   "e'er",
#   'wear',
#   'open',
#   'fill',
#   'bring',
#   'roll',
#   'thumb',
#   'shut',
#   'start',
#   'sew',
#   'cook',
#   "it's",
#   'fame',
#   'hear',
#   'rattle',
#   'advance',
#   'acknowledge',
#   'wait',
#   'till',
#   'hope',
#   'send',
#   'sea',
#   'pole',
#   'earth',
#   'ruin',
#   'continue',
#   'understand',
#   'fail',
#   'don',
#   're',
#   'sunset',
#   'stand',
#   'breathe',
#   'hire',
#   'protect',
#   'learn',
#   'explain',
#   'sketch',
#   'apartment',
#   'kiss',
#   'sharpen',
#   'stretch',
#   'holiness',
#   'themself',
#   '–',
#   'censor',
#   'bark',
#   'scoff',
#   'rage',
#   'bite',
#   'find',
#   'compare',
#   'mean',
#   'survive',
#   'damn',
#   "i'm"],
#  'CC': ['and', 'nor', 'but', 'or', '&', '—', 'ye'],
#  'DT': ['the',
#   'no',
#   'this',
#   'a',
#   'any',
#   'those',
#   'an',
#   'neither',
#   'some',
#   'another',
#   'all',
#   'that',
#   'these',
#   'every',
#   'booth',
#   'both',
#   'each'],
#  'JJ': ['precious',
#   'robust',
#   'poor',
#   'dingy',
#   'loosened',
#   'last',
#   'little',
#   'big',
#   'slow',
#   '—',
#   'quick',
#   'enough',
#   'second',
#   'next',
#   'i',
#   'popular',
#   'busy',
#   'aware',
#   'scared',
#   'many',
#   'early',
#   'drunk',
#   'happy',
#   'forty-nine',
#   'strange',
#   'single',
#   'fifty',
#   'dead',
#   'good',
#   'first',
#   'brown',
#   'racist',
#   'gun',
#   'bernie',
#   'vietnam',
#   'national',
#   'gay',
#   'unwritten',
#   'scorn',
#   'ageless',
#   'half-grown',
#   'coiled',
#   'long',
#   'treacherous',
#   'old',
#   "noon's",
#   'new',
#   'wide',
#   'white',
#   'angry',
#   'black',
#   's',
#   'loud',
#   'm',
#   'mad',
#   'birth',
#   'janae',
#   'rihanna',
#   '"',
#   'southern',
#   '’',
#   'wanna',
#   'curls',
#   'natural',
#   'nap',
#   'red',
#   'kardashian',
#   'iggy',
#   'afros',
#   'much',
#   'hood',
#   'nikki',
#   'aunt',
#   'sweet',
#   'smile',
#   'full',
#   'haughty',
#   'same',
#   'skinned',
#   'safe',
#   '”',
#   'soft',
#   'rare',
#   'blind',
#   'light',
#   'magic',
#   'clear',
#   'hungry',
#   'empty',
#   'asphalt',
#   'invisible',
#   'visible',
#   'thick',
#   'spanish',
#   'opposite',
#   'free',
#   'thy',
#   'contemptible',
#   'thee',
#   'adventurous',
#   'small',
#   'rigorous',
#   "labor's",
#   'unwearying',
#   'desperate',
#   'main',
#   'unmerciful',
#   'mortal',
#   'prick',
#   'consciousness',
#   "so's",
#   'sable',
#   'half-healed',
#   'valient',
#   "herder's",
#   'spilt',
#   "freedom's",
#   'void',
#   'own',
#   'humble',
#   'unjust',
#   'tyrant',
#   'constant',
#   'wild',
#   'sikh',
#   'muslim',
#   'lantern',
#   'inglorious',
#   'o',
#   'common',
#   'open',
#   'll',
#   'murderous',
#   'thou',
#   "god's",
#   'self',
#   'live',
#   'smooth',
#   'green',
#   'sturdy',
#   'true',
#   'ye',
#   'other',
#   'giddy',
#   'frivolous',
#   'utmost',
#   'mine',
#   'liberty',
#   'cherished',
#   'noble',
#   'fellow',
#   'inner',
#   'mighty',
#   'dire',
#   'impossible',
#   'final',
#   'shit',
#   'important',
#   're',
#   'alive',
#   've',
#   'high',
#   'acceptable',
#   'excellent',
#   'combat',
#   'superlative',
#   'ready',
#   'pointless',
#   '…',
#   'hard',
#   'gonna',
#   'terrifying',
#   'sorry',
#   "man's",
#   'great',
#   'deep',
#   'eternal',
#   'solemn',
#   'ill-apportioned',
#   'equal',
#   'such',
#   'wert',
#   'wept',
#   'fifth',
#   'silent',
#   'unpausing',
#   'factual',
#   'untested',
#   'molten',
#   'dark',
#   'wooded',
#   'twilit',
#   'grave-eyed',
#   'unknown',
#   'secret',
#   'phenomenal',
#   'cool',
#   't',
#   'real',
#   'proud',
#   'perfect',
#   'strive',
#   'unachievable',
#   'possible',
#   'only',
#   'different',
#   'unattainable',
#   'low',
#   'difficult',
#   'face-down',
#   'vaulted',
#   'noontide',
#   'feathery',
#   'blue',
#   'fearless',
#   'fair',
#   'voluptuous',
#   'free-born',
#   "o'er",
#   'glorious',
#   'goodly',
#   'bright',
#   "i'll",
#   'craven',
#   'weak',
#   'bleak',
#   'diet',
#   'rich',
#   'fat',
#   'false',
#   "something's",
#   'willing',
#   'stark',
#   'naked',
#   'stiff',
#   'bad',
#   'waterproof',
#   'shatterproof',
#   "they'll",
#   'twenty-five',
#   'wrong',
#   "warrior's",
#   'tear-drop',
#   'mid',
#   'rent',
#   'sacred',
#   'few',
#   'holy',
#   'temporal',
#   'happiness',
#   'agreeable',
#   'civil',
#   "nation's",
#   'closed',
#   'anxious',
#   'glad',
#   'thin',
#   'past',
#   'united',
#   'easy',
#   'sure',
#   'brazen',
#   'greek',
#   'sea-washed',
#   'imprisoned',
#   'world-wide',
#   'mild',
#   'air-bridged',
#   'twin',
#   'ancient',
#   'storied',
#   'tired',
#   'huddled',
#   'wretched',
#   'lamp',
#   'golden',
#   'canine',
#   'filmy-eyed',
#   'gilded',
#   'puerto',
#   'blank',
#   'drunken',
#   'wet',
#   'drive',
#   'wooden',
#   'gray',
#   'industrial',
#   'buried',
#   'gutted',
#   '“',
#   'furred',
#   'grained',
#   'oil-stained',
#   'prose',
#   '–',
#   'rumble',
#   "it's",
#   'private',
#   'censorious',
#   'hermetic',
#   'hot',
#   'dangerous',
#   'lascivious',
#   'sharp',
#   'strong',
#   'proper',
#   'heavy'],
#  'NNS': ['words',
#   'days',
#   'wings',
#   'yes',
#   'stomachs',
#   'bars',
#   'people',
#   'nights',
#   'i',
#   'years',
#   'guns',
#   'men',
#   'kisses',
#   'women',
#   'carnations',
#   'rifles',
#   'aids',
#   'stoops',
#   'errors',
#   'entrails',
#   'divinities',
#   'sisters',
#   'witches',
#   'cloths',
#   'futures',
#   'wilds',
#   'douglas',
#   'girls',
#   'braids',
#   'hairs',
#   'scarves',
#   'crowns',
#   'hands',
#   'movies',
#   'lips',
#   'songs',
#   'birds',
#   'roses',
#   'buggers',
#   'bastards',
#   'stars',
#   'beaches',
#   'moons',
#   'maidens',
#   'carts',
#   'clothes',
#   'trashcans',
#   'payers',
#   'booths',
#   'officers',
#   'belts',
#   'jackets',
#   't',
#   'buttercups',
#   'peninsulas',
#   'dungeons',
#   'shackles',
#   'allurements',
#   'snares',
#   'thinkers',
#   'regions',
#   'brothers',
#   'lands',
#   'bodies',
#   'heroes',
#   'medals',
#   'scars',
#   'trophies',
#   'mars',
#   'marks',
#   'deeds',
#   'cattle',
#   'letters',
#   'fetters',
#   'slaves',
#   'things',
#   'chains',
#   'links',
#   'eyes',
#   'fragments',
#   'books',
#   'foreheads',
#   'judges',
#   'lights',
#   'shadows',
#   'pairs',
#   'fades',
#   'strangers',
#   'drops',
#   'knees',
#   'high-tops',
#   'aunties',
#   'dupattas',
#   'uncles',
#   'palms',
#   'jasmines',
#   'constellations',
#   'names',
#   'hogs',
#   'dogs',
#   'monsters',
#   'kinsmen',
#   'flowers',
#   'friends',
#   'prophets',
#   'god',
#   'dwells',
#   'strains',
#   'knells',
#   'chalices',
#   'loves',
#   'worldlings',
#   'longings',
#   'dreams',
#   'blossoms',
#   'winds',
#   'sweets',
#   'odors',
#   'hearts',
#   'foam-bells',
#   'world-records',
#   'times',
#   'tears',
#   'boots',
#   'heels',
#   'converse',
#   'teeth',
#   'jeans',
#   'cheerleaders',
#   'm',
#   'fields',
#   'utters',
#   'beckons',
#   'pennons',
#   'rulers',
#   'theirs',
#   'treasures',
#   'scientists',
#   'rivers',
#   'ones',
#   'farmers',
#   'bees',
#   'badlands',
#   'facts',
#   'trees',
#   'boulders',
#   'drivers',
#   'stockers',
#   'writers',
#   'machinists',
#   'accountants',
#   'cellists',
#   'sounds',
#   'grows',
#   '"',
#   'girds',
#   'lies',
#   'arms',
#   'hips',
#   'fellows',
#   'feet',
#   'breasts',
#   'ads',
#   'vegetables',
#   'stores',
#   'imperfections',
#   "don't",
#   'towards',
#   'shoes',
#   'eaglets',
#   'lightnings',
#   'thunders',
#   'torrents',
#   'sons',
#   'mountains',
#   'watch-towers',
#   'plains',
#   'flights',
#   'pilgrims',
#   'haunts',
#   'expires',
#   'fires',
#   'sires',
#   'stripes',
#   'limbs',
#   'tyrants',
#   'children',
#   'mothers',
#   'casts',
#   'tyrannies',
#   'title-deeds',
#   'stitches',
#   'teacups',
#   'headaches',
#   '—',
#   'bombs',
#   'dissembles',
#   'hangs',
#   'trembles',
#   'bolts',
#   'sheds',
#   'rights',
#   'thousands',
#   'waits',
#   'fates',
#   'fears',
#   'elates',
#   'ten',
#   'mouths',
#   'echoes',
#   'notes',
#   'states',
#   'oceans',
#   'gates',
#   'exiles',
#   'glows',
#   'cities',
#   'cries',
#   'masses',
#   'blacks',
#   'ricans',
#   'cops',
#   'nightsticks',
#   'handcuffs',
#   'signs',
#   'parasites',
#   'bruises',
#   'sacks',
#   'acids',
#   'shafts',
#   'dollies',
#   'grow',
#   'hills',
#   'barns',
#   'stumps',
#   'bones',
#   'muscles',
#   'posts',
#   'cars',
#   'balls',
#   'glues',
#   'trotters',
#   'kinks',
#   'hams',
#   'caves',
#   '“',
#   '”',
#   'reeds',
#   'shovels',
#   'sins',
#   '–',
#   'boys',
#   'stories',
#   'tongues',
#   'claws',
#   'taunts',
#   'fantasies',
#   'dregs',
#   'wars',
#   'hummingbirds',
#   'doors'],
#  ',': [','],
#  'PRP$': ['his', 'my', 'our', 'their', 'your', 'her', 'its', 'hill'],
#  'NN': ['spirit',
#   'frame',
#   'dust',
#   'bequest',
#   'book',
#   'liberty',
#   'night',
#   'gay',
#   'bar',
#   'man',
#   'i',
#   'dinner',
#   'drink',
#   'far-back',
#   'backyard',
#   'place',
#   "it's",
#   'time',
#   'crowd',
#   'saturday',
#   'day',
#   'half-block',
#   'home',
#   'goodnight',
#   'stoop',
#   '—',
#   'sort',
#   'kiss',
#   "that's",
#   'guess',
#   'street',
#   'sidewalk',
#   'weekend',
#   'audience',
#   'fear',
#   'act',
#   'resistance',
#   'idea',
#   'hate',
#   'club',
#   'today',
#   'interview',
#   'father',
#   'sight',
#   'power',
#   'proof',
#   "men's",
#   'desire',
#   'violence',
#   "i've",
#   'one',
#   'consequence',
#   'bullet',
#   'sound',
#   'laugh',
#   "they'd",
#   'die',
#   'coincidence',
#   'country',
#   'thinking',
#   'boston',
#   'photograph',
#   'flower',
#   'protestor',
#   'placing',
#   'guard',
#   'gesture',
#   'queer',
#   'simple',
#   'protester',
#   'photo',
#   'hibiscus',
#   "government's",
#   'response',
#   'crime',
#   'president',
#   "can't",
#   'love',
#   'part',
#   'orlando',
#   'brooklyn',
#   'kabul',
#   "there's",
#   'world',
#   'corner',
#   'kissing',
#   'moon',
#   'sun',
#   'magic',
#   'sea',
#   'shape',
#   'favor',
#   'blood',
#   'curse',
#   'permanent',
#   'pride',
#   'pity',
#   'look',
#   'uranus',
#   'restless',
#   'pound',
#   'birth',
#   'dahomey',
#   'mother',
#   'mourning',
#   'woman',
#   'beware',
#   'smile',
#   'fury',
#   'poem',
#   'loud',
#   '’',
#   'mad',
#   'cuz',
#   'm',
#   'attention',
#   'see',
#   'jesus',
#   'prefer',
#   'control',
#   'rice',
#   's',
#   'fault',
#   'call',
#   'quvenzhane',
#   'wallis',
#   'reminder',
#   't',
#   'get',
#   'hair',
#   'gabby',
#   'head',
#   'gold',
#   'neck',
#   'nothing',
#   'rope',
#   'chain',
#   'america',
#   '‘',
#   'revolution',
#   'perm',
#   'wearin',
#   'gellin',
#   'baby',
#   'access',
#   'experience',
#   'crack',
#   'comb',
#   'raw',
#   'skin',
#   'magazine',
#   'lineage',
#   'booty',
#   'miley',
#   'cyrus',
#   'azalea',
#   'ghetto',
#   'straw',
#   'vacation',
#   'everyone',
#   'voice',
#   'braids',
#   'buns',
#   'rat',
#   'minaj',
#   'jemimah',
#   'syrup',
#   'singing',
#   'racism',
#   'sexism',
#   'patriarchy',
#   'misogyny',
#   'colorism',
#   'damn',
#   'dark',
#   'brother',
#   'door',
#   'kneel',
#   'pray',
#   'god',
#   'alive',
#   'human',
#   'hell',
#   'lot',
#   'poison',
#   'air',
#   'song',
#   'cannot',
#   'candy',
#   'anger',
#   'oak',
#   'elm',
#   'seldom',
#   'despair',
#   'murmur',
#   'din',
#   'light',
#   'sky',
#   'till',
#   'peacetime',
#   'sing',
#   'midnight',
#   'dirt',
#   'tax',
#   'line',
#   'paint',
#   'fence',
#   'road',
#   'office',
#   'building',
#   'iron',
#   'pole',
#   'beginning',
#   'hi',
#   'problem',
#   'way',
#   'side',
#   'direction',
#   'food',
#   'meadow-bee',
#   'visit',
#   'police',
#   'bee',
#   'raft',
#   'row',
#   'deem',
#   'freedom',
#   'heart',
#   "liar's",
#   'art',
#   'crafty',
#   'guide',
#   'greed',
#   'mart',
#   'opulence',
#   'hide',
#   'quest',
#   'greatness',
#   'spring',
#   "justice's",
#   'test',
#   'progress',
#   'hut',
#   'hall',
#   'zest',
#   'earth',
#   'bloody',
#   'darkness',
#   'dearth',
#   "tyrant's",
#   'reign',
#   'pierce',
#   'evil',
#   'domain',
#   'win',
#   'shatter',
#   'prison',
#   'rack',
#   "soul's",
#   'bone',
#   'bolder',
#   'saw',
#   'scymitar',
#   'eagle',
#   'thou',
#   'thine',
#   'enemy',
#   'captivity',
#   'triumphant',
#   'bright',
#   'service',
#   'life',
#   'limb',
#   'hand',
#   'sole',
#   'gain',
#   'battle',
#   'claim',
#   'aim',
#   'democracy',
#   'eclipse',
#   'opportunity',
#   'orator',
#   'speak',
#   '"',
#   'city',
#   'gate',
#   'fireside',
#   'tyrant',
#   'praise',
#   'ay',
#   'grove',
#   'temple',
#   'shadow',
#   'citadel',
#   'yoke',
#   'handcuff',
#   'harness',
#   'goal',
#   'fulfillment',
#   'care',
#   'want',
#   'grief',
#   'unbound',
#   'dawn',
#   'hour',
#   'truth',
#   'glitter',
#   'self',
#   'law',
#   'forehead',
#   'despot',
#   'throne',
#   'rule',
#   'proud',
#   'tyranny',
#   'shame',
#   'won',
#   'seat',
#   'half',
#   'embrace',
#   'repugnant',
#   'cherished',
#   'pursued',
#   'fetter',
#   'dance',
#   'sari',
#   'kin',
#   'sew',
#   'star',
#   'breast',
#   'toddler',
#   'stroller',
#   'fountain',
#   'dandelion',
#   'seed',
#   'bakery',
#   'uncle',
#   'airport',
#   'pat',
#   'car',
#   'traffic',
#   'azan',
#   'muslim',
#   'whiskey',
#   'start',
#   'maghrib',
#   'lone',
#   'khala',
#   'park',
#   'kurta',
#   'crocs',
#   'compass',
#   'teenager',
#   'snapback',
#   'subway',
#   'platform',
#   'mashallah',
#   'image',
#   'come',
#   'winter',
#   'flock',
#   'sand',
#   'colony',
#   'glass',
#   'wood',
#   'fire',
#   'spot',
#   'round',
#   'mock',
#   'accursèd',
#   'vain',
#   'foe',
#   'thousand',
#   'death-blow',
#   'grave',
#   'pack',
#   'wall',
#   'child',
#   "god's",
#   'seal',
#   'brow',
#   'o',
#   'stem',
#   'grow',
#   'apart',
#   "other's",
#   "river's",
#   'flow',
#   'bank',
#   'rock',
#   'river',
#   'daughter',
#   'timeless',
#   'past',
#   'bell',
#   'peace',
#   'story',
#   'bunker',
#   'clime',
#   "year's",
#   'eve',
#   'peal',
#   'music',
#   'swell',
#   'blue',
#   'living',
#   'thirsting',
#   'mouth',
#   'sorrow',
#   'track',
#   'gayety',
#   'dreamer',
#   'dream',
#   "earth's",
#   'bound',
#   'alone',
#   'lightsomeness',
#   'pure',
#   'friendship',
#   'change',
#   'edge',
#   'chill',
#   'contact',
#   'reality',
#   'sedge',
#   'burden',
#   'drench',
#   'ecstasy',
#   'gaze',
#   'azure',
#   'arc',
#   'flame',
#   'meteor',
#   'finger',
#   'thro',
#   'abyss',
#   'wherein',
#   'immortality',
#   'suffering',
#   'prayer',
#   'plan',
#   'need',
#   'soul',
#   'good',
#   'whole',
#   'thee',
#   'land',
#   'battle-fire',
#   'bed',
#   'pain',
#   'toll',
#   'triumph',
#   "spirit's",
#   'blow',
#   'thing',
#   'room',
#   'notice',
#   '”',
#   'doesn',
#   'matter',
#   'shit',
#   'body',
#   'hairstyle',
#   'morning',
#   'makeup',
#   'knife',
#   'brand',
#   'denim',
#   'combat',
#   'note',
#   'metaphor',
#   'sister',
#   'girl',
#   'thrift',
#   'store',
#   'jake',
#   'jane',
#   'someone',
#   'gonna',
#   'medal',
#   'honor',
#   'everything',
#   'cry',
#   'boon',
#   'cup',
#   'crust',
#   'luxury',
#   "king's",
#   'inmost',
#   'cave',
#   'morning-star',
#   'eoan',
#   'wave',
#   'wisdom',
#   'self-moving',
#   'cloud',
#   'ye',
#   'thought',
#   'blind',
#   'justice',
#   'fame',
#   'hope',
#   'name',
#   'wise',
#   'wind',
#   'buds',
#   'fruit',
#   'silence',
#   'speaking',
#   'gravity',
#   'earless',
#   'tongueless',
#   'bus',
#   'shelf',
#   'code',
#   'lab',
#   'techs',
#   'bow',
#   'lash',
#   'metal',
#   'behold',
#   'ajar',
#   'beckoning',
#   'veer',
#   'reckoning',
#   'sleeping',
#   'tarn',
#   'hill',
#   'save',
#   'homing',
#   'mystery',
#   'dusk',
#   'drowsy',
#   'murmurs',
#   'cease',
#   'whence',
#   'word',
#   'fearless',
#   'strength',
#   'fashion',
#   'model',
#   'size',
#   'reach',
#   'span',
#   'stride',
#   'step',
#   'curl',
#   'hive',
#   'honey',
#   'flash',
#   'swing',
#   'waist',
#   'joy',
#   'touch',
#   'arch',
#   'back',
#   'ride',
#   'grace',
#   'style',
#   'shout',
#   'jump',
#   'passing',
#   'click',
#   'bend',
#   'palm',
#   'cause',
#   "i'm",
#   "i'll",
#   'perfection',
#   'something',
#   'society',
#   'anyone',
#   'anything',
#   'ideal',
#   'person',
#   'obsession',
#   'addiction',
#   'selfesteem',
#   'depression',
#   'cliche',
#   'disappearance',
#   'boat',
#   'report',
#   "mountain's",
#   'crest',
#   'roaring',
#   'foam',
#   'dash',
#   'henceforth',
#   'type',
#   'aërie',
#   'dome',
#   'sunbeam',
#   'airy',
#   'flight',
#   'float',
#   'flood',
#   'liquid',
#   'ray',
#   'bask',
#   'blaze',
#   'tireless',
#   'wing',
#   'poise',
#   'steep',
#   'leap',
#   'canopy',
#   'dear',
#   'revelry',
#   'high',
#   'patriot',
#   'band',
#   'glory',
#   'watch',
#   'sentinel-track',
#   'banner',
#   'exult',
#   'dwell',
#   'tale',
#   'heritage',
#   "columbia's",
#   'beacon-hight',
#   'starless',
#   'pennon',
#   'fair',
#   'olive-branch',
#   'blast',
#   'launch',
#   'flagstaff',
#   'wrench',
#   'flee',
#   'race',
#   'slavery',
#   'very',
#   'echo',
#   'tis',
#   'pay',
#   'cell',
#   'use',
#   'loom',
#   'plough',
#   'sword',
#   'spade',
#   'defence',
#   'nourishment',
#   'whilst',
#   'riot',
#   'eye',
#   'ghost',
#   'toil',
#   'thousandfold',
#   'substance',
#   'paper',
#   'coin',
#   'forgery',
#   'hold',
#   'worth',
#   'inheritance',
#   'teeth',
#   'crutch',
#   'brace',
#   'hook',
#   'rubber',
#   'crotch',
#   'stop',
#   'crying',
#   'end',
#   'dissolve',
#   'stock',
#   'salt',
#   'suit',
#   'fit',
#   'roof',
#   'bury',
#   'ticket',
#   'closet',
#   'fifty',
#   'doll',
#   'talk',
#   'hole',
#   'poultice',
#   'boy',
#   'resort',
#   'maid',
#   'sash',
#   'while',
#   'drooping',
#   'starry',
#   'tear',
#   'drop',
#   'field',
#   'wife',
#   "husband's",
#   'cheering',
#   'asunder',
#   'war',
#   "e'er",
#   'son',
#   'brave',
#   'brief',
#   'loving',
#   'sod',
#   'magistratal',
#   'institution',
#   'laud',
#   'aubaud',
#   'source',
#   'nature',
#   'supreme',
#   'guardian',
#   "freedom's",
#   'thrill',
#   'hearth',
#   'church',
#   'manifest',
#   'divine',
#   'congress',
#   'suspense',
#   'bellman',
#   'decision',
#   'length',
#   'reply',
#   'ring',
#   'watching',
#   'proclaim',
#   'employ',
#   "people's",
#   'news',
#   'tell',
#   'tonight',
#   'moment',
#   'loneliness',
#   'isolation',
#   'share',
#   'history',
#   'membrane',
#   'election',
#   'infinity',
#   'money',
#   'deception',
#   'giant',
#   'torch',
#   'lightning',
#   'beacon-hand',
#   'welcome',
#   'command',
#   'harbor',
#   'keep',
#   'pomp',
#   'refuse',
#   'shore',
#   'homeless',
#   'tempest-tost',
#   'beer',
#   'company',
#   'puerto',
#   'picket',
#   'schaefer',
#   'pavilion',
#   'york',
#   'crowds',
#   'hostility',
#   'brewery',
#   'dead',
#   'cat',
#   'overrun',
#   'hallway',
#   'incinerator',
#   'mute',
#   'question',
#   'school',
#   'mirror',
#   'darker',
#   'face',
#   'doorway',
#   'tooth',
#   'jail',
#   'boycott',
#   'haircut',
#   'leaflet',
#   'netherworld',
#   'elevator',
#   'f',
#   'cops',
#   'disappointment',
#   'sign',
#   'miracle',
#   'burlap',
#   'butter',
#   'bean',
#   'slate',
#   'bread',
#   'rage',
#   'candor',
#   'tar',
#   'creosote',
#   'gasoline',
#   'rain',
#   'virginia',
#   'ass',
#   'pig',
#   'ferocity',
#   'ear',
#   'jowl',
#   'repose',
#   'hung',
#   'purpose',
#   'fist',
#   'thorax',
#   'arm',
#   'inherit',
#   'burning',
#   'lion',
#   '–',
#   'brain',
#   'bird',
#   'treason',
#   'tomb',
#   'hidden',
#   'ground',
#   'turning',
#   'point',
#   'view',
#   'property',
#   'texts',
#   'iconoclasm',
#   'bravado',
#   'salute',
#   "they're",
#   'box',
#   'boo',
#   "father's",
#   'piece',
#   'feel',
#   'tree',
#   'heard',
#   "haven't",
#   'house',
#   'storm',
#   'rebel'],
#  'VBD': ['grew',
#   'knew',
#   'was',
#   'danced',
#   'went',
#   'had',
#   'sat',
#   'asked',
#   'said',
#   'walked',
#   'kissed',
#   'were',
#   'wanted',
#   'decided',
#   'left',
#   'died',
#   'lettered',
#   'married',
#   'marked',
#   'did',
#   '’',
#   's',
#   'hit',
#   'draped',
#   'traced',
#   'won',
#   'bowed',
#   't',
#   'skinned',
#   'started',
#   'sunburned',
#   'spoke',
#   'liked',
#   'tight',
#   'fell',
#   'answered',
#   'bled',
#   'naked',
#   'erected',
#   'survived',
#   'mirrored',
#   'saw',
#   'set',
#   'consoled',
#   'used',
#   'studied',
#   'worked',
#   'began',
#   'surprised',
#   'kept',
#   'held',
#   'washed',
#   'rose',
#   'quenched',
#   'dewed',
#   'passed',
#   'joined',
#   'brandished',
#   'disappeared',
#   'told',
#   'dumped',
#   'appeared',
#   'returned',
#   'searched',
#   'bow',
#   'turned',
#   'opened',
#   'shut',
#   'put',
#   'thought',
#   'suppressed'],
#  ':': [';', ':', '-'],
#  'RBR': ['more', 'less', 'better'],
#  'IN': ['that',
#   'along',
#   'of',
#   'with',
#   'after',
#   'in',
#   'though',
#   'for',
#   'on',
#   '—',
#   'because',
#   'as',
#   'whether',
#   'without',
#   'out',
#   'while',
#   'by',
#   'whoever',
#   'from',
#   'about',
#   'around',
#   'behind',
#   'if',
#   'into',
#   'within',
#   'wear',
#   'inside',
#   'than',
#   'before',
#   'like',
#   'through',
#   'at',
#   'above',
#   'empty',
#   'between',
#   'upon',
#   'over',
#   'bind',
#   'except',
#   'among',
#   'beyond',
#   'unless',
#   'down',
#   'o',
#   'beneath',
#   "o'er",
#   'toward',
#   '“',
#   'below',
#   'against',
#   'accept',
#   'excuse',
#   'since',
#   'despite',
#   'beside',
#   'amid',
#   'under',
#   'laugh'],
#  '.': ['.', '!', '?'],
#  'WP': ['what', 'who', 'whom'],
#  'VBZ': ['brings',
#   'closes',
#   'is',
#   'has',
#   "didn't",
#   'names',
#   'makes',
#   'turns',
#   'oceans',
#   '’',
#   'annie',
#   'beasts',
#   'looks',
#   'represents',
#   'sips',
#   'wants',
#   'twists',
#   'walks',
#   'll',
#   'rots',
#   'captives',
#   'knits',
#   'means',
#   'slays',
#   'becomes',
#   'lingers',
#   'loses',
#   'apologizes',
#   'abandons',
#   'blows',
#   'lies',
#   'decks',
#   'hems',
#   'waves',
#   'fleets',
#   'dulls',
#   'trembles',
#   'crawls',
#   'helps',
#   'sharpens',
#   'fits',
#   'goes',
#   'happens',
#   'fucks',
#   's',
#   'comes',
#   '"',
#   'bids',
#   'falls',
#   'guards',
#   'gives',
#   'says',
#   "doesn't",
#   "that's",
#   'sweep',
#   'reigns',
#   '—',
#   'works',
#   'marry',
#   'binds',
#   'records',
#   'girds',
#   'speaks',
#   'conceals',
#   'presses',
#   'breathes',
#   'blesses',
#   'weighs',
#   'affirm',
#   'proves',
#   'exclaims',
#   'responds',
#   'shouts',
#   'escapes',
#   'depends',
#   'i',
#   'saves',
#   'sometimes',
#   '“',
#   'pulls',
#   '”',
#   'needs',
#   'does'],
#  'TO': ['to'],
#  'VBP': ['love',
#   "don't",
#   'live',
#   'call',
#   'are',
#   "aren't",
#   'i',
#   "didn't",
#   'slept',
#   "can't",
#   'believe',
#   "couldn't",
#   'have',
#   'cannot',
#   "i'm",
#   'know',
#   'am',
#   'die',
#   'run',
#   'seek',
#   'do',
#   '’',
#   'think',
#   'slick',
#   'mean',
#   'get',
#   'don',
#   'start',
#   'tell',
#   'look',
#   '“',
#   'pay',
#   'didn',
#   'understood',
#   'walk',
#   'tempt',
#   'find',
#   'insure',
#   'prostrate',
#   'wear',
#   'cease',
#   'girdle',
#   'rise',
#   'break',
#   'pour',
#   'move',
#   'claim',
#   'see',
#   'come',
#   'step',
#   'turn',
#   'grind',
#   'bell',
#   'follow',
#   'hear',
#   'map',
#   'bark',
#   'let',
#   'defy',
#   'face',
#   'seem',
#   'give',
#   'craze',
#   'chase',
#   'round',
#   'steal',
#   'gleams',
#   'behold',
#   'make',
#   'say',
#   'want',
#   'remember',
#   'deserve',
#   'need',
#   '"',
#   'lead',
#   'rend',
#   'gaze',
#   'wonder',
#   'please',
#   'stand',
#   'swarm',
#   'try',
#   'understand',
#   'build',
#   'rock',
#   'crash',
#   'fly',
#   'dart',
#   'scorn',
#   'pine',
#   'peak',
#   'speak',
#   'lie',
#   'ye',
#   "it's",
#   'weep',
#   'cry',
#   'thousand',
#   'swell',
#   "o'er",
#   'abandon',
#   'refuse',
#   'lift',
#   'lion',
#   'feed',
#   'sack',
#   'go',
#   '–',
#   'take',
#   '—',
#   'grown',
#   'grow',
#   'meant',
#   "shouldn't"],
#  'MD': ['will',
#   'would',
#   'might',
#   'can',
#   'must',
#   'shall',
#   'could',
#   'may',
#   'should',
#   'ought'],
#  'WRB': ['when', 'where', 'how', 'why', '—'],
#  'VBG': ['going',
#   'watching',
#   'wondering',
#   'kissing',
#   'imagining',
#   'wishing',
#   'thinking',
#   'getting',
#   'unrelenting',
#   'seeking',
#   'paying',
#   'demanding',
#   'conquering',
#   'twerking',
#   'mourning',
#   'lilting',
#   'starting',
#   'prisoning',
#   'ravening',
#   'turning',
#   'earning',
#   'understanding',
#   'burning',
#   'washing',
#   'being',
#   'cling',
#   'dissolving',
#   'dangling',
#   'pairing',
#   'gracing',
#   'smashing',
#   'opening',
#   'making',
#   'dying',
#   'fighting',
#   'ring',
#   'imparting',
#   'sing',
#   'beholding',
#   'tossing',
#   'dragging',
#   'daring',
#   'trusting',
#   'meeting',
#   'dealing',
#   'trying',
#   'stealing',
#   'hearing',
#   'killing',
#   'telling',
#   'posting',
#   'holding',
#   'saying',
#   'moving',
#   'feeling',
#   'missing',
#   'lying',
#   'wearing',
#   'smoldering',
#   'fluttering',
#   'surfeiting',
#   'smiling',
#   'responding',
#   'looking',
#   'yearning',
#   'teeming',
#   'glaring',
#   'studying',
#   'grinning',
#   'swelling',
#   'riding',
#   'bearing',
#   'hardening',
#   'eating',
#   'calling',
#   'passing',
#   'coming',
#   'breaking',
#   'pushing',
#   'thrusting',
#   'working',
#   'leading',
#   'growing',
#   'poking'],
#  'RB': ['anywhere',
#   'soon',
#   'properly',
#   'not',
#   'too',
#   'close',
#   'together',
#   'i',
#   'just',
#   'always',
#   'there',
#   'exactly',
#   'ago',
#   'inside',
#   'recently',
#   'ever',
#   'about',
#   'so',
#   'suddenly',
#   'away',
#   'else',
#   'also',
#   'now',
#   'imperfectly',
#   'here',
#   'down',
#   'everywhere',
#   'nowhere',
#   'back',
#   'still',
#   'first',
#   'instead',
#   'never',
#   'quite',
#   'somewhere',
#   'belly',
#   'even',
#   'only',
#   'then',
#   'up',
#   'maybe',
#   'indefinite',
#   'long',
#   'aside',
#   'far',
#   'therefore',
#   'homeward',
#   'short',
#   'partly',
#   'yet',
#   'as',
#   'indeed',
#   'rather',
#   'verily',
#   'thus',
#   't',
#   've',
#   'ahead',
#   'nobly',
#   'cowardly',
#   'very',
#   'alike',
#   'kindly',
#   'heard',
#   'again',
#   'proudly',
#   'sacredly',
#   'surely',
#   'therein',
#   'drouth',
#   'madly',
#   'fondly',
#   'whitely',
#   'sore',
#   'stoutly',
#   'gladly',
#   'completely',
#   'right',
#   'already',
#   'perfectly',
#   'however',
#   'sometimes',
#   'actually',
#   'someday',
#   'loudly',
#   'no',
#   'freely',
#   'softly',
#   'pretty',
#   'phenomenally',
#   'enough',
#   'seemingly',
#   'unhappiness',
#   'aloft',
#   'swiftly',
#   "o'er",
#   'well',
#   'tear',
#   'ye',
#   'empty',
#   'sweetie',
#   "she'll",
#   'silver',
#   'heaven',
#   'alone',
#   'bravely',
#   'nightly',
#   'creaturely',
#   'depress',
#   's',
#   'little',
#   'proven',
#   'almost',
#   'astride',
#   'later',
#   'easily',
#   'opon',
#   'apart',
#   "it's",
#   "i've",
#   'out',
#   'whoever'],
#  'CD': ['one',
#   'queer',
#   'two',
#   'thousand',
#   'three',
#   'four',
#   'five',
#   'six',
#   'seven',
#   'eight',
#   'nine',
#   '1948',
#   'knew',
#   '1964',
#   '14'],
#  'VBN': ['pressed',
#   'killed',
#   'been',
#   'disturbed',
#   'cursed',
#   'known',
#   'kissed',
#   'shot',
#   'touched',
#   'untouched',
#   'promised',
#   'sterilized',
#   'televised',
#   'scrubbed',
#   'told',
#   'cast',
#   'seen',
#   'heard',
#   'deferred',
#   'ended',
#   'arrayed',
#   'given',
#   'issued',
#   'fastened',
#   'written',
#   'destroyed',
#   'chosen',
#   'imposed',
#   'feared',
#   'desired',
#   'dreaded',
#   'lost',
#   'made',
#   'hunted',
#   'penned',
#   'shed',
#   'constrained',
#   'outnumbered',
#   'found',
#   'darkened',
#   'sung',
#   'vanished',
#   'jacked',
#   'called',
#   'survived',
#   'tried',
#   'failed',
#   'fashioned',
#   'charioted',
#   'disjoined',
#   'bought',
#   'forbidden',
#   'silenced',
#   'taken',
#   'continued',
#   'left',
#   'sandalled',
#   'gone',
#   'wondered',
#   'bowed',
#   'capsized',
#   'set',
#   'grown',
#   'keeps',
#   'guaranteed',
#   'naked',
#   'doomed',
#   'poured',
#   'received',
#   'employed',
#   'expressed',
#   "o'er",
#   'passed',
#   'relieved',
#   'attached',
#   'voted',
#   'loved',
#   'tasted',
#   'torn',
#   'framed',
#   'shut',
#   'pounded',
#   'come',
#   'driven',
#   'forgiven',
#   'hidden',
#   'peeped',
#   'lodged',
#   'i',
#   'buried'],
#  'EX': ['there'],
#  'WDT': ['which', 'that', 'whatever'],
#  '(': ['('],
#  ')': [')'],
#  'JJS': ['most',
#   'best',
#   'nest',
#   'divest',
#   'mayest',
#   'freest',
#   'strongest',
#   'sweetest',
#   'deadliest',
#   'prettiest',
#   'lest',
#   'closest',
#   'worst',
#   'west'],
#  'NNP': ['’', '"', '—', '“', '”'],
#  'JJR': ['y',
#   'less',
#   'hunger',
#   'better',
#   'easier',
#   'greater',
#   'more',
#   'liberty',
#   'longer',
#   's',
#   'fewer',
#   'older'],
#  'FW': ['vogue', '"', 'noon'],
#  'RP': ['out', 'up', 'away', 'off', 'down', 'over', 'back'],
#  'PDT': ['doth', 'hope', 'm', 's', 'all'],
#  'POS': ["'"],
#  'UH': ['alas', 'yes'],
#  "''": ["'"],
#  'RBS': ['most'],
#  '``': ['`'],
#  'WP$': ['whose']}

# %%
sequences
# Out:
# [['PRP', 'VB', 'CC', 'VB', 'DT', 'JJ', 'NNS', ','],
#  ['PRP$', 'NN', 'VBD', 'JJ', ':'],
#  ['PRP', 'VBD', 'DT', 'RBR', 'IN', 'PRP', 'VBD', 'JJ', ','],
#  ['CC', 'IN', 'PRP$', 'NN', 'VBD', 'NN', '.'],
#  ['PRP', 'VBD', 'IN', 'DT', 'JJ', 'NNS', ','],
#  ['CC', 'DT', 'NN', 'IN', 'NNS'],
#  ['VBD', 'CC', 'DT', 'NN', '.', 'WP', 'NN'],
#  ['DT', 'JJ', 'NN', 'VBZ', '.'],
#  ['JJ', 'NN', ',', 'VB', 'VBD', 'TO', 'DT', 'NN', 'NN'],
#  ['IN', 'DT', 'NN', 'NN', 'VBP', 'DT', 'JJ', '.'],
#  ['IN', 'NN', ',', 'PRP', 'VBD', 'DT', 'NN', '.'],
#  ['PRP', 'VBD', 'IN', 'DT', 'NN', 'IN', 'DT', 'JJ', 'NN'],
#  ['CC',
#   'PRP',
#   'VBD',
#   ',',
#   'WP',
#   'MD',
#   'PRP',
#   'VB',
#   'WRB',
#   'DT',
#   'NN',
#   'VBZ',
#   '.'],
#  ['NN',
#   'VBP',
#   'VB',
#   'NN',
#   'VBG',
#   'RB',
#   'DT',
#   'NN',
#   'RB',
#   ',',
#   'NN',
#   'VBD',
#   ','],
#  ['IN', 'DT', 'NN', 'VBD', 'JJ', 'IN', 'DT', 'NN', ','],
#  ['CC',
#   'PRP',
#   'VBD',
#   'JJ',
#   'NNS',
#   ',',
#   'CC',
#   'CD',
#   'NN',
#   '.',
#   'WRB',
#   'MD',
#   'PRP',
#   'VB',
#   '.'],
#  ['PRP', 'VBD', 'PRP', 'DT', 'NN', 'NN'],
#  ['CC', 'VBD', 'PRP', 'NN', 'IN', 'PRP$', 'NN', 'NN'],
#  ['RB', ':', 'RB', 'RB', 'JJ', ',', 'RB', 'JJ'],
#  ['PRP$', 'NNS', 'VBN', 'RB'],
#  ['IN', 'DT', 'JJ', 'NN', 'IN', 'NN', '.'],
#  ['RB', 'VBP', 'JJ', 'TO', 'DT', 'NN', 'NN', 'RB', 'DT', 'NN', 'NN'],
#  ['IN', 'PRP', 'RB', 'VBP', 'DT', 'NNS', ',', 'JJ', 'NN', 'NN'],
#  ['CC', 'IN', 'PRP', 'VBZ', 'JJ'],
#  ['CC', 'IN', 'JJ', 'VBP', 'IN', 'DT', 'JJ', 'NN', ','],
#  ['EX', 'VBP', 'RB', 'NNS', 'WP', 'VBP', 'CD', 'NNS'],
#  ['IN', 'DT', 'NN', 'IN', 'NN', 'NNS', '.'],
#  ['RB', 'NNS', ',', 'JJ', 'NN', '.'],
#  ['PRP', 'VBD', 'RB', 'JJ', 'NN', '.'],
#  ['IN', 'NN', 'VBD', 'DT', 'NN', 'NN', 'VBD', 'JJ', 'IN', 'PRP', 'VBG'],
#  ['CC', 'IN', 'PRP', 'VBG', 'IN', 'CC', 'RB', 'PRP', 'VBD', 'RB', '.'],
#  ['CC', 'VBP', 'VBP', 'VB', 'PRP', 'VB', 'JJ', ',', 'NNS', 'VBD', 'PRP'],
#  ['RB',
#   'IN',
#   'NN',
#   'VBD',
#   'TO',
#   ',',
#   'IN',
#   'NN',
#   'MD',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   ','],
#  ['IN', 'NN', 'VBD', 'JJ', 'NNS', 'RB', 'TO', 'VB', 'DT', 'NN', 'NN'],
#  ['DT', 'NN', 'IN', 'NN', '.', 'NN', 'VBD'],
#  ['DT', 'NN', 'IN', 'NN', 'IN', 'IN', 'DT', 'NN', 'CC', 'VBD', 'RB', ','],
#  ['TO', 'VB', ',', 'JJ', 'CC', 'JJ', 'CC', 'JJ', '.'],
#  ['IN', 'JJ', 'VBP', ',', 'DT', 'NN', 'VBD', 'TO', 'DT', 'NN', 'NN'],
#  ['IN', 'CD', 'NNS', 'CC', 'VBN', 'JJ', 'NNS', '.'],
#  ['NN',
#   'IN',
#   'DT',
#   'NN',
#   ',',
#   'PRP$',
#   'NN',
#   'VBD',
#   'PRP',
#   'VBD',
#   'VBN',
#   'VBN'],
#  ['RB', 'IN', 'DT', 'NN', 'IN', 'CD', 'NNS', 'VBG', '.'],
#  ['WP', 'DT', 'JJ', 'NN', 'TO', 'VB', 'VBN', 'IN', ':'],
#  ['IN', 'DT', 'NN', 'IN', 'NN', 'NN', 'TO', 'VB', 'NNS', 'TO', 'NN', '.'],
#  ['VB', 'DT', 'JJ', 'NN', '.', 'NN', 'VBD', 'NNS'],
#  ['DT', 'NN', 'VBZ', 'RB', 'VBN', 'RB', ',', 'RB', 'JJ'],
#  ['NNS', 'IN', 'NN', 'NN'],
#  ['CC', 'EX', 'VBZ', 'DT', 'NN', 'PRP', 'VBP', 'VB', ','],
#  ['IN', 'PRP', 'VBP', '.'],
#  ['EX', 'MD', 'VB', 'DT', 'NN', 'WRB', '.'],
#  ['PRP', 'MD', 'VB', 'DT', 'NN', ',', 'RB', '.'],
#  ['DT', 'NN', 'IN', 'PRP', '.', 'JJ', '.'],
#  ['CD', 'NN', ',', 'CD', 'NNS', ',', 'JJ', 'JJ', 'NN'],
#  ['CD', 'NNS', 'VBG', '.', 'JJ', 'NN'],
#  ['NN', 'VBP', 'VB', 'RB', 'IN', ',', 'VBG', 'PRP', ',', 'PRP', ','],
#  ['DT', 'NNS', 'RB', 'TO', 'VB', 'CC', 'NN', 'CC', 'NN', ','],
#  ['WP', 'VBZ', 'VBP', 'NN', 'NN', ',', 'WP', 'VBP', 'VBP', '.'],
#  ['WRB', 'RB', 'MD', 'PRP', 'VB', 'DT', 'JJ', 'NN', '.'],
#  ['WRB', 'RB', 'MD', 'PRP', 'VB', '.'],
#  ['RB', 'MD', 'VB', 'VBN', 'CD', 'NNS', 'VBG'],
#  ['IN', 'DT', 'JJ', 'NN', 'JJ', 'NN', ',', 'CC', 'IN', 'DT', 'JJ', ','],
#  ['CC',
#   'CD',
#   'NNS',
#   ',',
#   'RB',
#   ',',
#   'CC',
#   'CD',
#   'NNS',
#   'WP',
#   'VBD',
#   'DT',
#   '.'],
#  ['JJ', 'NNS', ',', 'WDT', 'VBP', 'VB', 'DT', 'NN', 'IN', 'DT', 'NN'],
#  ['WDT', 'VBZ', 'DT', 'JJ', 'NN', ',', 'WDT', 'VBZ', 'JJ', 'NN', '.'],
#  ['NN', 'VBP', 'NN', 'IN', 'DT', 'JJ', 'NN', 'NN'],
#  ['NN', 'NN', ',', 'IN', 'DT', 'JJ', 'NN', 'NN', 'NNS'],
#  ['IN', 'DT', 'NNS', 'IN', 'DT', 'JJ', 'NN', ','],
#  ['CC', 'VBG', 'IN', 'DT', 'NN', 'IN', 'NN', 'CC', 'NN', '.'],
#  ['DT', 'NN', 'IN', 'DT', 'NN', 'VBD', 'JJ', ',', 'PRP', 'VBP', ','],
#  ['PRP', 'VBD', 'IN', 'NN', 'CC', 'VBD', 'IN', 'NNS', ','],
#  ['WDT', 'NN', 'VBP', 'RB', 'VBG', 'IN', 'NN', 'IN'],
#  ['(', 'DT', 'NN', 'NN', 'TO', ')', 'NNS', 'VBD', 'DT', 'NN', 'NN', '.'],
#  ['RB', 'PRP', 'VBP', 'DT', 'NN', 'WP', 'VBZ', 'PRP', ','],
#  ['DT', 'JJ', 'CC', 'RB', 'VBD', 'PRP', ',', 'CC', 'RB', 'PRP', 'VBP'],
#  ['VBG', 'VBN', 'IN', 'NNS', ',', 'VBG', 'VBD', 'DT', 'IN', 'PRP', ','],
#  ['DT', 'IN', 'PRP', 'VBG', 'VBN', '.'],
#  ['PRP', 'MD', 'VB', 'CD', 'DT', 'IN', 'CC', 'RB', 'PRP', 'VBP', '.'],
#  ['VB', 'NN', 'VB', 'DT', 'NN'],
#  ['CC', 'DT', 'MD', 'PRP', 'VB', 'VBN', 'RB', ','],
#  ['CC',
#   'NN',
#   'VBZ',
#   ',',
#   'IN',
#   'DT',
#   'JJS',
#   'NN',
#   ',',
#   'WP',
#   'VBZ',
#   'PRP',
#   'VB'],
#  ['IN', 'NN', 'CC', 'IN', 'NN', 'CC', 'IN', 'NN', '.'],
#  ['PRP', 'MD', 'VB', 'RB', ',', 'RB', ':'],
#  ['NN', 'RB', 'RB', 'IN', 'PRP', ',', 'CC', 'PRP', ',', 'TO', 'VB', '.'],
#  ['RB',
#   'PRP',
#   'VBP',
#   'IN',
#   'DT',
#   'NN',
#   ',',
#   'VB',
#   'MD',
#   'VB',
#   'RB',
#   'TO',
#   'VB',
#   'PRP',
#   '.'],
#  ['IN', 'DT', 'NN', ',', 'EX', 'MD', 'VB', 'CD', 'NNS', '.', 'NN', '.'],
#  ['NN', 'VBD', 'CC', 'VBN', 'IN', 'NN'],
#  ['PRP$', 'NN', 'VBZ', 'JJ'],
#  ['CC', 'WRB', 'DT', 'NN', 'VBZ', 'RB'],
#  ['PRP', 'MD', 'VB', 'PRP$', 'NN', 'IN', '.'],
#  ['NN', 'VBP', 'DT', 'NN'],
#  ['VBN', 'IN', 'NN'],
#  ['VBG', 'IN', 'DT', 'NN', 'IN', 'NN'],
#  ['NN', 'IN', 'PRP$', 'NNS'],
#  ['CC', 'PRP$', 'NN'],
#  ['NNS', 'VBP', 'RB', 'VB'],
#  ['NN', 'IN', 'NN'],
#  ['CC', 'NN', 'IN', 'JJ'],
#  ['CC', 'IN', 'PRP', 'MD', 'VB', 'PRP'],
#  ['NN', 'IN', 'DT', 'NNS', 'IN', 'NN'],
#  ['WRB', 'DT', 'NN', 'VBZ', 'NN', '.'],
#  ['NNS', 'VBP', 'RB', 'VB'],
#  ['IN', 'PRP$', 'NN', 'CC', 'PRP$', 'NNS'],
#  ['WP', 'VBP', 'JJ', 'CC', 'JJ'],
#  ['CC', 'RB', 'VBG'],
#  ['PRP$', 'NNS'],
#  ['NNS', 'IN', 'NN'],
#  ['IN', 'PRP', 'IN', 'PRP$', 'JJ', 'NNS'],
#  ['IN', 'PRP$', 'NN', 'VBD'],
#  ['NN', '.'],
#  ['NNS', 'VBP', 'VBN', 'NN'],
#  ['IN', 'DT', 'JJ', 'NN'],
#  ['NN', 'PRP$', 'NN'],
#  ['NN', 'VBP', 'JJ', 'IN', 'JJ', 'NN'],
#  ['CC', 'DT', 'JJ', 'JJ', 'NN'],
#  ['IN', 'DT', 'PRP$', 'JJ', 'NNS'],
#  ['VBN'],
#  ['NN', 'VBP'],
#  ['NN'],
#  ['CC', 'RB', 'JJ', '.'],
#  ['DT', 'VBZ', 'PRP$', 'JJ', 'JJ', 'NN', 'NN', '.'],
#  ['PRP',
#   'VBZ',
#   'JJ',
#   'NN',
#   '.',
#   'PRP',
#   'VBD',
#   'JJ',
#   'JJ',
#   '.',
#   'PRP',
#   'VBZ',
#   'JJ',
#   'JJ',
#   '.',
#   'PRP',
#   'VBD',
#   'JJ',
#   'NN',
#   '.'],
#  ['PRP',
#   'VBZ',
#   'JJ',
#   'NN',
#   'CC',
#   'PRP',
#   'VBZ',
#   'JJ',
#   'JJ',
#   'CC',
#   'PRP',
#   'VBZ',
#   'JJ',
#   'JJ',
#   'CC',
#   'PRP',
#   'NNP',
#   'VBD',
#   'NN',
#   'IN',
#   'JJR',
#   'NN',
#   'DT',
#   'VBP',
#   'TO',
#   'VB',
#   'PRP',
#   'VB',
#   'JJ',
#   'CC',
#   'JJ',
#   'CC',
#   'JJ',
#   'CC',
#   'NN',
#   '.'],
#  ['RB',
#   ',',
#   'VB',
#   'PRP',
#   'WRB',
#   'JJ',
#   'VBP',
#   'JJ',
#   'NN',
#   '.',
#   'JJ',
#   'VBP',
#   'JJ',
#   'JJ',
#   'NN',
#   'NN',
#   'VBP',
#   'NN',
#   'VBG',
#   'NN',
#   '.'],
#  ['NN',
#   ',',
#   'DT',
#   'NN',
#   'VBP',
#   'PRP',
#   'VBP',
#   '.',
#   'JJ',
#   'VBP',
#   'PRP$',
#   'NN',
#   'VBZ',
#   'JJ',
#   'CC',
#   'RB',
#   'PRP$',
#   'NN',
#   '.'],
#  ['NN', 'NN', 'VBP', 'VBN', 'IN', 'VB', 'JJ', 'NN', '.'],
#  ['VB',
#   'PRP',
#   'VBD',
#   'JJ',
#   'NN',
#   'NNP',
#   'NN',
#   'NN',
#   ',',
#   'VB',
#   'IN',
#   'JJ',
#   'VBD',
#   'PRP',
#   'RB',
#   ','],
#  ['NN',
#   'NN',
#   'NN',
#   'NNP',
#   'VBZ',
#   'JJ',
#   'RB',
#   'IN',
#   'DT',
#   'NN',
#   'WDT',
#   'VBZ',
#   'IN',
#   'DT',
#   'JJ',
#   'NNS',
#   'VBP',
#   'JJ',
#   'NN',
#   'NN',
#   'TO',
#   'VB',
#   'PRP',
#   '.'],
#  ['VB', 'DT', 'NN', 'IN', 'NN', 'NNS', 'VBP', 'NN'],
#  ['IN',
#   'DT',
#   'NN',
#   'VBD',
#   'IN',
#   'PRP$',
#   'NN',
#   'CC',
#   'WRB',
#   'PRP',
#   'VBZ',
#   'NN',
#   'IN',
#   'NN'],
#  ['CC',
#   'NN',
#   'CC',
#   'RB',
#   'VBZ',
#   'NN',
#   '.',
#   'JJ',
#   'VBP',
#   'JJ',
#   'JJ',
#   'NN',
#   'NN',
#   'PRP',
#   'RB',
#   'VB',
#   'NN',
#   'TO',
#   'VB',
#   'PRP$',
#   'NN',
#   '.'],
#  ['VB',
#   'DT',
#   'NN',
#   'MD',
#   'RB',
#   'VB',
#   'VBN',
#   'IN',
#   'PRP',
#   'MD',
#   'VB',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'PRP'],
#  ['CC',
#   'DT',
#   'JJ',
#   'NNS',
#   'JJ',
#   'VBP',
#   'VB',
#   'NNP',
#   'PRP$',
#   'JJ',
#   'JJ',
#   '.',
#   'NN',
#   'JJ',
#   'NNS',
#   'CC',
#   'NN',
#   'NNP',
#   'NN',
#   'NNS',
#   'IN',
#   'DT',
#   'NNP',
#   'VBD',
#   'JJ',
#   '.'],
#  ['VBG',
#   'NN',
#   'TO',
#   'DT',
#   'NN',
#   'WRB',
#   'PRP',
#   'MD',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'VBG',
#   'DT',
#   'NN',
#   ','],
#  ['DT', 'NN', 'IN', 'NN', 'VBN', 'JJ', 'CC', 'RB', 'RB', 'JJ', ','],
#  ['NN',
#   'VBP',
#   'NN',
#   'NN',
#   'IN',
#   'FW',
#   'NN',
#   'VBD',
#   'DT',
#   'NN',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NN',
#   'RB',
#   'TO',
#   'VB',
#   'JJ',
#   ','],
#  ['IN', 'RB', 'IN', 'NN', ',', 'NN', 'NN', 'VBZ', 'RB', 'VBG', ','],
#  ['IN',
#   'JJ',
#   'NN',
#   'VBZ',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'PRP',
#   'VBZ',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['VB',
#   'NN',
#   'VBZ',
#   'TO',
#   'VB',
#   'PRP',
#   'CC',
#   'PRP',
#   'VBD',
#   'NNP',
#   'NN',
#   'VB',
#   'PRP',
#   'VB',
#   'PRP',
#   '.',
#   'PRP',
#   'VBP',
#   'PRP',
#   'TO',
#   'VB',
#   'PRP$',
#   'NN',
#   ',',
#   'VB',
#   'PRP$',
#   'NN',
#   ','],
#  ['DT',
#   'NN',
#   'DT',
#   'NN',
#   'DT',
#   'VBZ',
#   'DT',
#   'JJ',
#   'DT',
#   'NNS',
#   'PRP',
#   'VBP',
#   'RB',
#   'JJ',
#   'IN',
#   'NNS',
#   '.',
#   'JJR',
#   'JJ',
#   'NN',
#   '.'],
#  ['RBR', 'JJ', 'NN', 'RBR', 'JJ', 'NN', ','],
#  ['VBN',
#   'TO',
#   'VB',
#   'DT',
#   'JJ',
#   'JJ',
#   'JJ',
#   'IN',
#   'NN',
#   ',',
#   'DT',
#   'RB',
#   'JJ',
#   'CC',
#   'NN',
#   ',',
#   'DT',
#   'NN',
#   'VBD',
#   'CC',
#   'DT',
#   'NNS',
#   'JJ',
#   '.'],
#  ['NN',
#   'VBP',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   ',',
#   'NN',
#   ',',
#   'NN',
#   ',',
#   'NN',
#   'CC',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'NN',
#   '.'],
#  ['IN',
#   'PRP',
#   'VBD',
#   'NNP',
#   'VBD',
#   'RB',
#   'VBN',
#   'NN',
#   'VBD',
#   'NNS',
#   'TO',
#   'VB',
#   'NN',
#   'JJ',
#   'NNS',
#   'IN',
#   'NNS',
#   'IN',
#   'NN',
#   'VBD',
#   'NNS',
#   '.'],
#  ['IN',
#   'DT',
#   'NN',
#   'PRP$',
#   'NN',
#   'VBZ',
#   'RP',
#   'IN',
#   'NN',
#   ',',
#   'DT',
#   'NNS',
#   'VBP',
#   'VB',
#   'JJ',
#   ',',
#   'JJ',
#   'NN',
#   'IN',
#   'PRP$',
#   'NNS',
#   'CC',
#   'JJ',
#   'NN',
#   'TO',
#   'DT',
#   'NN',
#   'NN',
#   'VBP',
#   'VBZ',
#   'RB',
#   'VB',
#   'IN',
#   'IN',
#   'PRP',
#   'VBZ',
#   'PRP$',
#   'NN',
#   'NN',
#   'NN',
#   '.'],
#  ['VBG', 'RB', 'IN', 'PRP', 'VBP', 'IN'],
#  [],
#  ['NN',
#   'VBP',
#   'NN',
#   'NN',
#   '.',
#   'NN',
#   'VBP',
#   'NN',
#   'NN',
#   '.',
#   'NN',
#   'RB',
#   'VB',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'JJ',
#   'IN',
#   '.'],
#  ['JJ', 'NNS', ',', 'IN', 'NNS', ',', 'NN', 'IN', 'NN', 'NN'],
#  ['RB', 'PRP$', 'NN', 'NN', 'RB', 'VB', 'NN', '.'],
#  ['NN', 'VBZ', 'DT', 'NN', 'CC', 'NN', ':', 'NNS', 'VBP', 'JJ', ','],
#  ['NN', 'VBN', 'IN', 'JJ', 'NN', '.'],
#  ['CC', 'PRP$', 'NN', 'NN', 'VB', 'VBN'],
#  ['IN', 'DT', 'NN', 'CC', 'NN', '.', 'DT', 'NN', 'VBZ', 'JJ'],
#  ['IN', 'NNS', 'CC', 'NNS', ':', 'DT', 'NN', 'CC', 'NNS'],
#  ['NN', 'DT', 'NN', '.', 'CC', 'PRP$', 'NN', 'VBZ', 'VBN'],
#  ['NN', 'NN', ',', 'WRB', 'PRP$', 'NN', 'MD', 'VB', 'JJ', ','],
#  ['IN', 'RB', ',', 'VBG', 'IN', 'DT', 'NN', ':', 'RB', 'MD', 'VB'],
#  ['NN', 'IN', 'NNS', ',', 'JJ', 'IN', 'DT', 'JJ', 'NN', ','],
#  ['CC', 'IN', 'NNS', 'CC', 'NNS', 'IN', 'NN', '.'],
#  ['PRP', 'VBD', 'JJ', 'PRP', 'VBD', 'JJ'],
#  ['IN', 'PRP$', 'NNS', 'IN', 'DT', 'NNS', 'IN', 'PRP$', 'JJ', 'NNS'],
#  ['PRP', 'VBD', 'JJ', 'IN', 'PRP$', 'NNS'],
#  ['VBD', 'JJ', 'PRP$', 'NNS', 'IN', 'NNS'],
#  ['DT', 'NNS', 'IN', 'DT', 'NN'],
#  ['DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'DT',
#   'NN',
#   'NN',
#   'NNS',
#   'VBP',
#   'IN'],
#  ['RB', 'TO', 'DT', 'JJ', 'NN', 'JJ', 'JJ', 'JJ', 'NN'],
#  ['JJ', 'NNS', 'JJ', 'IN', 'DT', 'NN', 'VBG', 'IN', 'DT', 'NNS'],
#  ['DT', 'NN', 'DT', 'NN', 'DT', 'NN', 'NN', 'NN', 'RB', 'DT', 'NN'],
#  ['NN', 'NN', 'NN'],
#  ['PRP', 'VBD', 'IN', 'DT', 'NN', 'IN', 'DT', 'NN', 'NN'],
#  ['RB', 'DT', 'NN', 'NN', 'IN', 'DT', 'NN'],
#  ['DT', 'NNS', 'DT', 'NNS', 'MD', 'VB', 'IN', 'NNS'],
#  ['VB', 'NN', 'TO', 'JJ', 'CC', 'JJ', 'NNS', 'DT', 'NN'],
#  ['DT', 'NN', 'NN', 'VBP', 'VBD', 'NNS', 'NNS', 'NNS'],
#  ['PRP', 'VBP', 'JJ', 'NNS', 'VBP', 'DT'],
#  ['CC', 'RB', 'RB', 'DT', 'NN'],
#  ['PRP$', 'NN', 'VBD', 'DT', 'IN', 'PRP', 'VBD', 'JJ'],
#  ['PRP',
#   'VBP',
#   'JJ',
#   'NN',
#   'VBP',
#   'WRB',
#   'PRP',
#   'VBD',
#   'VBN',
#   'RP',
#   'DT',
#   'NN'],
#  ['IN', 'DT', 'NN'],
#  ['PRP', 'VBP', 'JJ', 'NN', 'VB', 'WRB', 'PRP', 'VBD', 'VBN', 'RP', 'RB'],
#  ['PRP', 'VBP', 'JJ', 'NN', 'VBP', 'CC', 'PRP', 'VBP', 'WRB', 'PRP', 'VBP'],
#  ['DT', 'JJ', 'NN', 'TO', 'VB', 'NN', 'IN', 'DT', 'NN'],
#  ['DT', 'NN', 'PRP', 'DT', 'VBP', 'VBZ', 'JJR'],
#  ['MD', 'VB', 'CC', 'VB', 'RB', ','],
#  ['IN', 'PDT', 'DT', 'NN', ','],
#  ['CC', 'NN', 'RB', 'WRB', 'NN', 'VBD', ','],
#  ['CC', 'DT', 'NN', 'VB', 'PRP', ','],
#  ['CC', 'VB', 'DT', 'NN', 'IN', 'NNS', ','],
#  ['CC', 'VB', 'WP', 'NN', 'MD', ','],
#  ['CC', 'VB', 'DT', 'JJ', 'RB', ','],
#  ['CC', 'JJR', ',', 'VB', 'RP'],
#  ['IN', 'DT', 'NN', 'TO', 'VB', ','],
#  ['CC', 'VB', 'PRP', 'IN', 'JJ', 'VBP', ','],
#  ['NN', 'NN', 'MD', 'VB', 'NNS'],
#  ['TO', 'VB', 'RP', 'IN', 'PRP', ',', 'VB'],
#  ['NN', 'VBD', ',', 'CC', 'RB', 'TO', 'VB', 'DT', 'NN'],
#  ['IN', 'DT', 'NN', 'IN', 'NN', ','],
#  ['CC', 'NN', 'IN', 'RB', 'DT', 'NN', 'RB', ','],
#  ['CC', 'VB', 'RP', 'DT', 'NN', ',', 'NN'],
#  ['WP', 'NN', '.', 'RB', 'VBZ', 'NN'],
#  ['WP', 'VBD', 'IN', 'NNS', 'VBP', '.'],
#  ['NN', 'IN', 'NN', ',', 'VB', 'JJ', 'IN', 'JJ', 'NN', ':'],
#  ['JJ', 'IN', 'DT', 'NNS', 'IN', 'VBG', 'NN', ','],
#  ['JJ', 'IN', 'DT', 'NN', 'JJ', 'NN', ','],
#  ['JJ', 'IN', 'NNS', 'WDT', 'VBP', 'JJ', 'RB', ','],
#  ['JJ', 'IN', 'DT', 'NN', 'CC', 'JJ', 'NN', ','],
#  ['JJ', 'IN', 'DT', 'VBG', 'NN', 'IN', 'DT', 'NN', ','],
#  ['JJ', 'IN', 'DT', 'NNS', 'IN', 'IN', 'NN', 'NN', ',', 'NN'],
#  ['NN', 'IN', 'NN', 'VB', 'JJ', 'IN', 'JJ', 'NN', '.'],
#  ['NN', 'IN', 'NN', ',', 'VBP', 'NN', 'IN', 'DT', ':'],
#  ['NN', 'IN', 'NNS', 'POS', 'JJ', 'NN', ','],
#  ['NN', 'IN', 'NN', 'TO', 'NN', 'IN', 'DT', 'JJ', ','],
#  ['NN', 'IN', 'JJR', 'TO', 'VB', 'TO', 'DT', 'JJS', ','],
#  ['NN', 'IN', 'NN', 'JJ', 'NN', ','],
#  ['NN', 'IN', 'NN', 'IN', 'NN', 'CC', 'IN', 'NN', ','],
#  ['NN', 'IN', 'JJ', 'JJ', 'NN', ',', 'NN'],
#  ['NN', 'IN', 'NN', ',', 'VB', 'JJ', 'IN', 'PRP', 'DT', '.'],
#  ['NN', 'IN', 'NN', ',', 'VB', 'JJ', 'IN', 'DT', 'NN', ':'],
#  ['IN', 'DT', 'NN', 'CC', 'JJ', 'JJ', ','],
#  ['RB', 'IN', 'DT', 'NNS', 'IN', 'NN', 'CC', 'NN', ','],
#  ['VB', 'DT', 'NN', 'JJ', 'NN', ','],
#  ['NN', 'TO', 'DT', 'NN', 'IN', 'PRP$', 'NN', 'NN', ','],
#  ['NN', 'IN', 'JJ', 'NNS', 'DT', 'NNS', 'IN', 'PRP$', 'NN', ','],
#  ['NN', 'DT', 'NN', 'CC', 'VB', 'DT', 'NN', ',', 'NN'],
#  ['NN', 'IN', 'NN', ',', 'VB', 'JJ', 'IN', 'DT', 'NN', '.'],
#  ['DT', 'NN', 'MD', 'VB', 'PRP', ','],
#  ['PRP$', 'NN', 'IN', 'NN'],
#  ['IN', 'DT', 'JJ', 'NN'],
#  ['EX', 'VBZ', 'DT', 'NN', 'CD'],
#  ['PRP', 'VBP', 'JJ', 'IN', 'NN', ','],
#  ['CC', 'VB', 'IN', 'NN', '.'],
#  ['CD', 'NNS', 'RB', 'VB', ':'],
#  ['IN', 'CD', ',', 'CC', 'CD', 'MD', 'VB', '.'],
#  ['DT', 'NN', 'IN', 'PRP$', 'JJS'],
#  ['DT', 'JJR', 'JJS'],
#  ['CC', 'VB', 'DT', 'NN', ','],
#  ['IN', 'JJS', 'NN', ','],
#  ['IN', 'PRP', 'MD', 'VB'],
#  ['NN', 'NN', ':'],
#  ['NN', 'VBZ', 'JJ', ','],
#  ['JJ', 'NN', '.'],
#  ['NN', 'JJ', 'NNS', 'RB', 'VBG', ','],
#  ['VBN', 'IN', 'NNS', ',', 'NN', ',', 'CC', 'JJ', 'NNS', ','],
#  ['VBZ', 'NN', ',', 'NN', ',', 'CC', 'NN', 'VBN', 'VBN', 'VBG'],
#  ['NNS', ',', 'VBN', 'IN', 'DT', 'NN', 'IN', 'NNS', '.'],
#  ['IN',
#   'PRP$',
#   'NN',
#   'NN',
#   'VBZ',
#   'VBN',
#   'DT',
#   'FW',
#   'NNS',
#   'IN',
#   'NN',
#   ',',
#   'VB'],
#  ['IN', 'JJ', 'NNS', 'VBP', 'DT', 'JJR', 'NN', ','],
#  ['IN', 'PRP', 'VBP', 'RB', 'TO', 'VB', 'DT', 'JJ', 'NNS', ','],
#  ['RB', 'VB', 'JJ', 'NN', 'VBD', 'RB', 'IN', 'JJ', 'NN', '.'],
#  ['NN', 'VBZ', 'JJR', 'IN', 'JJ', 'NNS', ','],
#  ['CC', 'NN', 'RB', 'RBR', 'IN', 'RB', 'JJ', ':'],
#  ['RB',
#   ',',
#   'DT',
#   'VBP',
#   'JJ',
#   'RB',
#   'RB',
#   'IN',
#   'NNS',
#   ',',
#   'IN',
#   'NNS',
#   ','],
#  ['VBP', 'IN', 'NN', 'IN', 'NN', '.'],
#  ['CC',
#   'DT',
#   'NN',
#   'VBD',
#   ',',
#   'NNP',
#   'NN',
#   'TO',
#   'PRP',
#   'IN',
#   'NN',
#   '.',
#   'NN'],
#  ['CC', 'PRP', 'VBD', ':'],
#  ['IN',
#   'DT',
#   'NN',
#   'NN',
#   'CC',
#   'IN',
#   'PRP$',
#   'NN',
#   'NN',
#   'VBP',
#   'VBN',
#   'PRP',
#   'VBP',
#   'PRP',
#   'CC',
#   'VB',
#   'PRP$',
#   'JJ',
#   'NN',
#   ','],
#  ['RB',
#   'IN',
#   'NNS',
#   'JJ',
#   'PRP',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'NN',
#   'PRP',
#   'IN',
#   'PRP',
#   'VBZ',
#   'PRP',
#   '.'],
#  ['NN',
#   ',',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'VBP',
#   'VBN',
#   'DT',
#   'JJS',
#   'IN',
#   'PRP',
#   'VBP',
#   'PRP$',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'DT',
#   'NN',
#   '.'],
#  ['CC',
#   'PRP$',
#   'NN',
#   'VBD',
#   'IN',
#   'PRP',
#   ':',
#   'IN',
#   'PRP',
#   'MD',
#   'RB',
#   'VB',
#   'JJ',
#   'WRB',
#   'RB',
#   'DT',
#   'NN',
#   'IN',
#   'VBG',
#   'NN',
#   'VBZ',
#   'DT',
#   'NN',
#   'TO',
#   'PRP',
#   ',',
#   'CC',
#   'WRB',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'DT',
#   'NN',
#   '.'],
#  ['PRP',
#   'MD',
#   'VB',
#   'JJ',
#   'RB',
#   'WRB',
#   'PRP$',
#   'NNS',
#   'VBP',
#   'RB',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'PRP$',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'DT',
#   'NN',
#   ','],
#  ['CC',
#   'RB',
#   'WRB',
#   'DT',
#   'NNS',
#   'VBP',
#   'PRP$',
#   'NN',
#   'CC',
#   'RB',
#   'PRP',
#   'VBP',
#   'IN',
#   'PRP',
#   'VBD',
#   'CC',
#   'NN',
#   '.'],
#  ['CC',
#   'WRB',
#   'MD',
#   'PRP',
#   'VB',
#   'IN',
#   'PRP$',
#   'NNS',
#   'CC',
#   'NNS',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'NNS',
#   'WDT',
#   'PRP',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'PRP$',
#   'VBG',
#   'VBP',
#   'VBN',
#   'IN',
#   'PRP$',
#   'FW',
#   'NN',
#   '.'],
#  ['IN',
#   'NN',
#   'IN',
#   'WDT',
#   'PRP',
#   'VBP',
#   'NN',
#   'VBZ',
#   'DT',
#   'JJS',
#   'IN',
#   'DT',
#   'NNS',
#   ',',
#   'IN',
#   'PRP$',
#   'NNS',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'VB',
#   'DT',
#   'NNS',
#   '.'],
#  ['CC',
#   'WP',
#   'VBZ',
#   'PRP',
#   'CC',
#   'NNS',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NN',
#   'PRP',
#   'MD',
#   'VB',
#   'IN',
#   'PRP',
#   'MD',
#   'VB',
#   'JJ',
#   '.'],
#  ['IN',
#   'PRP',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'PRP',
#   'MD',
#   'VB',
#   ',',
#   'IN',
#   'NN',
#   'VBD',
#   'VBN',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NN',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NN',
#   '.'],
#  ['PRP',
#   'VBP',
#   'VB',
#   'PRP',
#   'IN',
#   'VBG',
#   'PRP$',
#   'NN',
#   'NNS',
#   'CC',
#   'IN',
#   'VBG',
#   'DT',
#   'NNS',
#   'IN',
#   'PRP$',
#   'NNS',
#   ',',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'IN',
#   'PRP',
#   '.'],
#  ['CC',
#   'IN',
#   'PRP',
#   'VBZ',
#   'DT',
#   'NN',
#   'PRP',
#   'MD',
#   'VB',
#   ',',
#   'VB',
#   'RB',
#   'IN',
#   'PRP$',
#   'NN',
#   'VBD',
#   'IN',
#   'PRP',
#   'VBZ',
#   'VBN',
#   '.'],
#  ['IN',
#   'WRB',
#   'MD',
#   'DT',
#   'JJ',
#   'NN',
#   'DT',
#   'JJ',
#   'CC',
#   'DT',
#   'NN',
#   ',',
#   'CC',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NN',
#   'CC',
#   'DT',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN',
#   'NN',
#   '.'],
#  ['CC',
#   'IN',
#   'PRP',
#   'VBZ',
#   'DT',
#   'NN',
#   'PRP',
#   'MD',
#   'VB',
#   'RP',
#   ',',
#   'DT',
#   'NN',
#   'VBZ',
#   'VBN',
#   'VBN',
#   'IN',
#   'PRP',
#   'RB',
#   'IN',
#   'VBN',
#   'IN',
#   'PRP',
#   '.'],
#  ['CC',
#   'IN',
#   'PRP',
#   'VBZ',
#   'DT',
#   'NN',
#   'PRP',
#   'MD',
#   'VB',
#   ',',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'VBZ',
#   'IN',
#   'PRP$',
#   'NN',
#   'CC',
#   'RB',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'VBN',
#   '.'],
#  ['RB',
#   'DT',
#   'NNS',
#   'VBP',
#   'IN',
#   'PRP$',
#   'VBG',
#   'IN',
#   'JJ',
#   'NN',
#   'NN',
#   ',',
#   'DT',
#   'VBN',
#   'CC',
#   'DT',
#   'VBN',
#   ',',
#   'DT',
#   'NN',
#   'CC',
#   'DT',
#   'NN',
#   ',',
#   'DT',
#   'NN',
#   'CC',
#   'IN',
#   'WDT',
#   'PRP',
#   'MD',
#   'VB',
#   '.'],
#  ['DT',
#   'NNS',
#   'VBP',
#   'IN',
#   'PRP',
#   'IN',
#   'NNS',
#   'CC',
#   'NNS',
#   'IN',
#   'NNS',
#   'IN',
#   'VBG',
#   '.'],
#  ['CC',
#   'WRB',
#   'DT',
#   'NN',
#   'NNS',
#   'CC',
#   'VBZ',
#   'DT',
#   'RBR',
#   ',',
#   'DT',
#   'NN',
#   'WDT',
#   'VBZ',
#   'VBZ',
#   'DT',
#   'NN',
#   'TO',
#   'DT',
#   'NN',
#   '.'],
#  ['CC',
#   'RB',
#   'PRP$',
#   'NN',
#   'WRB',
#   'PRP',
#   'VBZ',
#   'PRP$',
#   'NNS',
#   'VBZ',
#   'PRP',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'JJR',
#   'NN',
#   '.'],
#  ['DT', 'VBP', 'PRP$', 'NNS', 'CC', 'NN', 'VBP'],
#  ['PRP', 'IN', 'DT', 'NN', 'CC', 'NN'],
#  ['IN', 'DT', 'JJ', 'DT', 'JJ'],
#  ['PRP$', 'NNS', 'PRP$', 'NNS'],
#  ['DT', 'NN', 'IN', 'NNS', 'IN', 'PRP$', 'NN'],
#  ['DT', 'JJ', 'NN', 'NNP', 'NN', 'NN', 'VBG', 'TO', 'VB'],
#  ['VB', 'DT', 'JJ', 'NN', 'IN', 'PRP$', 'NN'],
#  ['JJ', 'NN', 'PRP$', 'PRP$', 'NN', 'CC', 'NN'],
#  ['DT', 'NN', 'IN', 'PRP$', 'TO', 'PRP$', 'NN'],
#  ['DT', 'NN', 'VBG', 'IN', 'NN'],
#  ['NN', 'DT', 'NN', 'IN', 'NN', 'NN'],
#  ['IN', 'DT', 'NN', 'NN', 'VBP', 'PRP', 'RB'],
#  ['DT', 'JJ', 'NN', 'IN', 'DT', 'NN'],
#  ['WP', 'VBZ', 'IN', 'DT', 'NN'],
#  ['IN', 'DT', 'JJ', 'NN', 'WP', 'VBZ'],
#  ['PRP$', 'NN', 'IN', 'DT', 'NN', 'JJ', 'NNS'],
#  ['TO', 'PRP$', 'NNS', 'IN', 'DT', 'NN', 'IN', 'DT', 'NN'],
#  ['CC', 'DT', 'NN', 'NN', 'WP', 'VBZ'],
#  ['JJ', 'NN', 'IN', 'DT', 'NN', 'IN', 'NN'],
#  ['DT', 'NN', 'NN', 'IN', 'DT', 'NN'],
#  ['VBG', 'PRP$', 'NN', 'IN', 'NN'],
#  ['PRP$', 'NNS', 'PRP$', 'NNS', 'VBP', 'MD', 'VB', 'RB', 'VB', 'VBN'],
#  ['WRB', 'NN', 'VBP', 'PRP', 'PRP$', 'NN'],
#  ['VBZ', 'JJ', 'CC', 'NN', 'CC', 'NN'],
#  ['PRP$', 'NN', 'DT', 'NN', 'NN'],
#  ['NN', 'CC', 'NNS', 'VBG'],
#  ['DT', 'NN', 'NN'],
#  ['NN', 'NN', 'VBP', 'PRP', 'DT'],
#  ['PRP$', 'NN', 'VBZ', 'VBN'],
#  ['IN', 'PRP$', 'NNS', 'VBP', 'JJ', 'NN'],
#  ['IN', 'PRP', 'VBP', 'IN', 'PRP', 'PRP'],
#  ['NN', 'IN', 'PRP', 'RB', 'IN', 'DT', 'JJ'],
#  ['IN', 'NN', 'DT', 'NN', 'IN'],
#  ['NNS', 'VBP', 'RP', 'IN', 'DT', 'NN'],
#  ['PRP$', 'NNS', 'VBP', 'TO', 'VB'],
#  ['DT', 'NN', 'IN', 'NNS', 'VBP', 'PRP$', 'NNS'],
#  ['CC', 'DT', 'CD', 'NNS', 'VBP', 'DT', 'NN'],
#  ['PRP$', 'NNS', 'VBP', 'VBP', 'PRP', 'IN', 'NNS'],
#  ['PRP', 'VBP', 'DT', 'NN', 'VBG', 'DT', 'NN'],
#  ['CC', 'DT', 'NNS', 'VBG', 'PRP$', 'NN'],
#  ['PRP$', 'NNS', 'DT', 'NN', 'VBZ', 'JJ', 'NN'],
#  ['IN', 'DT', 'NN', 'PRP$', 'NNS', 'PRP$', 'NNS'],
#  ['DT', 'JJ', 'NNS', 'PRP', 'VBP', 'RB', 'VBD', 'DT', 'JJ'],
#  ['NNS', 'RB', 'TO', 'VB', 'JJ', 'VBP', 'PRP', 'VBP'],
#  ['PRP$', 'NN', 'DT', 'JJ', 'PRP$', 'JJ', 'JJ'],
#  ['RB', 'CC', 'JJ', 'VBP', 'NNS', 'VBP'],
#  ['IN', 'PRP', 'MD', 'VB', ',', 'VB', 'PRP', 'RB', 'VB', 'IN', 'NNS'],
#  ['VBN', 'CC', 'VBN', 'IN', 'DT', 'JJ', 'NN', ','],
#  ['IN', 'NN', 'PRP', 'VBP', 'DT', 'NN', 'CC', 'JJ', 'NNS', ','],
#  ['VBG', 'PRP$', 'NN', 'IN', 'PRP$', 'NN', 'NN', '.'],
#  ['IN', 'PRP', 'MD', 'VB', ',', 'PRP', 'VBP', 'PRP', 'RB', 'VBP', ','],
#  ['RB', 'IN', 'PRP$', 'JJ', 'NN', 'MD', 'RB', 'VB', 'VBN'],
#  ['IN', 'NN', ':', 'RB', 'RB', 'DT', 'NNS', 'PRP', 'VBP'],
#  ['MD', 'VB', 'VBN', 'TO', 'VB', 'PRP', 'IN', 'JJ', '.'],
#  ['JJ', 'NNS', '.', 'PRP', 'MD', 'VB', 'DT', 'JJ', 'NN', '.'],
#  ['IN', 'RB', 'VBN', 'VB', 'PRP', 'VB', 'PRP', 'VB', ','],
#  ['CC', 'IN', 'PRP$', 'NN', 'VBZ', 'VB', 'CD', 'NN', '.'],
#  ['WP', 'IN', 'IN', 'PRP', 'VBZ', 'DT', 'JJ', 'NN', '.'],
#  ['IN', 'NNS', 'PRP', 'VBP', 'JJ', 'VBP', 'DT', 'JJ', ',', 'RB', 'NN', ','],
#  ['VBN', 'TO', 'DT', 'NN', ',', 'VBG', ',', 'CC', 'VBG', 'RB', '.'],
#  ['JJ', 'NN', ',', 'JJ', 'NN', 'IN', 'NN', ','],
#  ['NN', 'NN', 'VBZ', 'IN', 'JJ', 'NN', '.'],
#  ['NN', 'NN', ',', 'PRP$', 'NN', 'RB', 'CC', 'JJ', ','],
#  ['JJ', 'RB', 'JJ', 'NN', 'NN', '.'],
#  ['CD', 'NNS', 'RB', ',', 'RB', 'RB', 'RB', ','],
#  ['IN', 'DT', 'JJ', 'NN', 'WDT', 'NN', ','],
#  ['CD', 'NNS', 'WP', 'VBP', 'JJ', 'NN', ','],
#  ['RB', 'VBP', 'DT', 'NN', 'NN', '.'],
#  ['CD', ',', 'DT', 'JJ', 'NN', 'VBD', 'NN'],
#  ['WDT', 'VBZ', 'DT', 'NN', 'IN', 'JJ', ':'],
#  ['CC', 'CD', ',', 'DT', 'NN', 'IN', 'JJ', 'NN'],
#  ['WDT', 'VBZ', 'DT', 'NN', 'IN', '.'],
#  ['JJ', 'NN', 'IN', 'DT', 'NN', 'NN', ','],
#  ['IN', 'PDT', 'DT', 'NNS', 'VBD', ','],
#  ['NNS', 'VBP', 'PRP', 'NN', 'IN', 'NN'],
#  ['CC', 'NN', 'IN', 'NN', '.'],
#  ['VBG', 'IN', ',', 'VBG', 'IN', 'JJ', 'NN', 'NN'],
#  ['IN', 'NN', 'IN', 'NN', ',', 'JJ', 'MD', 'TO', 'NNS', '.'],
#  ['DT', 'NN', 'JJ', ',', 'JJ', 'RB', 'VBP', ','],
#  ['IN', 'NN', 'PRP$', 'IN', 'TO', 'VB', '.'],
#  ['IN', 'DT', 'NN', 'WRB', 'NN', 'NNS'],
#  ['PRP$', 'JJS', 'NNS', 'CC', 'VBG', 'NNS'],
#  ['IN', 'JJ', 'NN', 'NN', 'VBD', 'RB', 'RB', '.'],
#  ['NN', 'IN', 'NN', ',', 'PRP$', 'NN', 'NN'],
#  ['IN', 'DT', 'NN', 'DT', 'JJ', 'CC', 'JJ'],
#  ['DT', 'VBZ', 'RB', 'RB', 'NN', 'IN', 'DT', 'NN'],
#  ['CC', 'RB', 'RB', 'IN', 'DT', 'JJ', '.'],
#  ['DT', 'NN', ',', 'NN', 'VBD', 'DT', 'NN', 'IN', 'PRP$', 'NN'],
#  ['TO', 'DT', 'NN', 'NNS', 'IN', 'NNS', 'WDT', 'VBP', '.'],
#  ['RB', ',', 'UH', ',', 'NNS', 'VBP', 'VBN', 'RB', 'CC', 'RB', ','],
#  ['RB', 'VBZ', 'NN', 'VBN', 'IN', 'PRP$', 'NNS', '.'],
#  ['IN', 'NNS', 'VBP', 'DT', 'JJ', 'RB', 'VBP'],
#  ['PRP$', 'JJ', 'NN', 'IN', 'JJ', 'NN', ','],
#  ['NN', ',', 'PRP$', 'NN', 'NN', 'JJ', 'NNS', 'NN', ':'],
#  ['CD', 'NN', 'NN', 'VBZ', 'JJ', ',', 'PRP$', 'NN', 'VBZ', 'JJ', '.'],
#  ['NNS', 'VBP', 'VBN', 'PRP', 'DT', ':', 'CC', 'VB', 'NN', 'WDT', 'VBZ', ','],
#  ['NN', 'NN', ',', 'PRP$', 'JJS', 'RB', 'JJ', 'NNS', ','],
#  ['JJ', 'NNS', 'CC', 'DT', 'NNS', 'WDT', 'VBP', 'PRP$', 'NNS', ','],
#  ['NN', 'NNS', ',', 'CC', 'DT', 'NN', 'WDT', 'RB', 'VBP', '.'],
#  ['CC', 'PRP$', 'NNS', 'NN', ':', 'DT', 'NN', 'VBZ', 'PRP$', 'NN'],
#  ['IN', 'DT', 'NN', 'NN', 'IN', 'NN', ':'],
#  ['DT', 'VBN', 'IN', 'DT', 'NNS', 'IN', 'DT', 'NN', ':'],
#  ['NN', 'VBG', 'CD', 'NN', 'RB', ',', 'PRP$', 'NN', 'VBZ', 'JJ', '.'],
#  ['NN', 'NN', 'PRP$', 'NN', 'IN', 'NN', ',', 'VBD', ','],
#  ['CC', 'PRP$', 'NN', 'VBZ', 'IN', 'DT', 'NN', 'NN', ','],
#  ['WRB', 'IN', 'DT', 'JJ', 'NNS', 'NNS', 'VBP'],
#  ['NN', 'IN', 'DT', 'NN', 'NN', 'NN', 'NN', "''", 'DT', 'NN'],
#  ['CC', 'IN', ',', 'IN', 'NNS', ',', 'VBD', 'IN', 'DT', 'NN'],
#  ['NN', 'NN', 'VBZ', 'IN', 'NN', ',', 'NN'],
#  ['VBG', 'RB', 'WRB', 'RB', 'PRP$', 'NN', 'VBZ', ','],
#  ['NNS', 'VBP', 'PRP$', 'NN', 'IN', 'NNS', ',', 'PRP', 'VBZ', 'IN', 'NN', '.'],
#  ['JJ', 'NNP', 'JJ', 'NN', 'WP', 'VBP', 'DT', 'JJ', '.'],
#  ['DT', ',', 'JJ', 'NN', ',', 'WP', 'VBP', 'JJ', 'TO', 'VB', ':'],
#  ['JJ', 'TO', 'DT', 'NN', 'IN', 'DT', 'JJ', 'NN', ','],
#  ['JJ', 'TO', 'DT', 'NN', 'IN', 'PRP$', 'JJ', 'NN', ','],
#  ['JJ', 'TO', 'DT', 'NN', 'IN', 'DT', 'JJ', 'NN', ','],
#  ['JJ', 'TO', 'DT', 'NN', 'IN', 'DT', 'JJ', 'NN', ','],
#  ['JJ', ',', 'JJ', 'NN', ',', 'TO', 'PRP$', 'NNS', 'CC', 'NN', ','],
#  ['DT', 'IN', 'DT', 'IN', 'DT', 'VBP', 'DT', 'JJ', '.'],
#  ['WRB', 'NN', 'WRB', 'NN', 'WRB', 'VBP', 'DT', 'JJ', ','],
#  ['WRB', 'IN', 'NN', 'CC', 'DT', 'VBG', 'NN', '.'],
#  ['EX', 'VBP', 'PRP', 'WRB', 'DT', 'NN', 'VBZ', 'JJ', ','],
#  ['EX', 'VBP', 'PRP', 'IN', 'DT', 'NN', ','],
#  ['EX', 'VBP', 'PRP', 'IN', 'DT', 'NN', 'IN', 'NN', ','],
#  ['RB', 'PRP', 'VBP', 'VBG', 'DT', 'NN', 'NN', ','],
#  ['WRB', 'DT', 'NN', 'CC', 'DT', 'NN', 'VB', ','],
#  ['RB', 'WRB', 'EX', 'VB', 'EX', 'VBP', 'DT', 'JJ', '.'],
#  ['WRB', 'JJ', 'WRB', 'JJ', 'WRB', 'MD', 'DT', 'JJ'],
#  ['VB', 'DT', 'NN', 'IN', 'PRP$', 'NN', '.'],
#  ['RB', 'VBG', 'JJ', 'NNS', ','],
#  ['RB', 'VBG', 'DT', 'NN', 'NNS', ','],
#  ['RB', 'VBG', 'DT', 'JJS', 'NN', ','],
#  ['RB', 'VBG', 'DT', 'JJ', 'NN', ','],
#  ['RB', 'VBG', 'IN', 'NN', ','],
#  ['JJ', 'NNP', 'JJ', 'IN', 'DT', 'VBP', 'DT', 'JJ', '.'],
#  ['CD',
#   ',',
#   'DT',
#   'NN',
#   'VBZ',
#   'VBG',
#   'TO',
#   'VB',
#   'PRP',
#   '.',
#   'PRP',
#   'VBZ',
#   'VBG',
#   'TO',
#   'VB',
#   'DT',
#   'IN',
#   'VBG',
#   'PRP$',
#   'NN',
#   '.',
#   'VB',
#   'PRP',
#   'RB',
#   '.'],
#  ['CD',
#   ',',
#   'PRP',
#   'VBP',
#   'DT',
#   'JJS',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   '.',
#   'PRP',
#   'VBP',
#   'JJ',
#   'NN',
#   'NN',
#   'VBD',
#   'RB',
#   'VB',
#   'IN',
#   'DT',
#   'JJS',
#   'NN',
#   '.',
#   'PRP',
#   'VBP',
#   'RB',
#   'DT',
#   'JJS',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   ',',
#   'CC',
#   'IN',
#   'JJ',
#   'NN',
#   'NNP',
#   'NN',
#   'NN',
#   '.',
#   'IN',
#   'NN',
#   'VBZ',
#   'DT',
#   'NN',
#   'VBG',
#   'TO',
#   'VB',
#   'PRP',
#   '.',
#   'CD',
#   ',',
#   'PRP',
#   'VBP',
#   'JJ',
#   'RB',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN',
#   'VBZ',
#   'DT',
#   'RBS',
#   'JJ',
#   'NN',
#   'IN',
#   'PRP',
#   '.',
#   'IN',
#   'NN',
#   'VBZ',
#   'RB',
#   '.',
#   'CC',
#   'IN',
#   'PRP',
#   'VBP',
#   'JJ',
#   'JJ',
#   ',',
#   'CC',
#   'VBG',
#   'PRP',
#   'VBP',
#   'DT',
#   'NNS',
#   'RB',
#   'RB',
#   ',',
#   'RB',
#   'PRP',
#   'VBP',
#   'JJ',
#   'RB',
#   'VB',
#   'PRP',
#   'RB',
#   'JJ',
#   'NNS',
#   '.'],
#  ['DT',
#   'VBD',
#   ',',
#   'CD',
#   ':',
#   'DT',
#   'JJS',
#   'NN',
#   'VBZ',
#   'CD',
#   'WDT',
#   'VBZ',
#   'PRP',
#   'VBP',
#   'IN',
#   'IN',
#   'NN',
#   'DT',
#   'NN',
#   '.',
#   'DT',
#   'JJS',
#   'NN',
#   'VBZ',
#   'CD',
#   'WDT',
#   'VBZ',
#   'DT',
#   'NN',
#   'IN',
#   'PRP',
#   '.',
#   'DT',
#   'JJS',
#   'NN',
#   'IN',
#   'NN',
#   'VBZ',
#   'CD',
#   'WDT',
#   'VBZ',
#   'CC',
#   'VBZ',
#   'IN',
#   'PRP$',
#   'NN',
#   'NNS',
#   '.',
#   'NN',
#   'WDT',
#   'JJ',
#   'NNS',
#   'VBP',
#   'RB',
#   'JJ',
#   'NN',
#   'NNS',
#   '.',
#   'NNS',
#   'VBP',
#   'JJ',
#   'NN',
#   'NNS',
#   ',',
#   'CC',
#   'UH',
#   ',',
#   'JJ',
#   'NNS',
#   'VBP',
#   'JJ',
#   'NN',
#   'NNS',
#   '.'],
#  ['CD',
#   ',',
#   'VBP',
#   'WDT',
#   'PRP',
#   'VBP',
#   ',',
#   'VBP',
#   'RB',
#   'PRP',
#   'VBP',
#   ':',
#   'PRP',
#   'VBP',
#   'WP',
#   'MD',
#   'VB',
#   'PRP',
#   'IN',
#   'PRP',
#   'VBP',
#   'JJ',
#   'NN',
#   'IN',
#   'PRP',
#   '.',
#   'NN',
#   '.'],
#  ['CD',
#   ',',
#   'PRP',
#   'VBP',
#   'IN',
#   'NN',
#   'IN',
#   'VBG',
#   'PRP',
#   'VBG',
#   'VBG',
#   'PRP$',
#   'NN',
#   '.',
#   'RB',
#   'DT',
#   'NN',
#   'MD',
#   'RB',
#   'VB',
#   'TO',
#   'VB',
#   'PRP',
#   '.',
#   'PRP',
#   'VBP',
#   'JJ',
#   'RB',
#   'VBP',
#   'PRP',
#   '.',
#   'VBG',
#   'PRP',
#   'TO',
#   'VB',
#   'JJ',
#   'VBZ',
#   'JJ',
#   '.',
#   'VBG',
#   'PRP',
#   'TO',
#   'VB',
#   'PRP',
#   'VBZ',
#   'RB',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'PRP',
#   'WRB',
#   'PRP',
#   'VBZ',
#   ',',
#   'WDT',
#   'VBZ',
#   'WRB',
#   'JJ'],
#  ['CD', ',', 'PRP', 'VBP', 'TO', 'VB', 'RP', 'PRP$', 'NNS', '.'],
#  ['CD',
#   ',',
#   'NN',
#   'VBZ',
#   'PRP$',
#   'NN',
#   '.',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'VBN',
#   'RP',
#   'NNS',
#   'CC',
#   'DT',
#   'NN',
#   'NN',
#   'NNS',
#   'VBZ',
#   'PRP$',
#   'NN',
#   '.',
#   'DT',
#   'NN',
#   'WP',
#   'VBZ',
#   'NNS',
#   'VBZ',
#   'PRP$',
#   'NN',
#   '.',
#   'DT',
#   'NN',
#   'WP',
#   'VBD',
#   'TO',
#   'VB',
#   'VBN',
#   'NN',
#   ',',
#   'CC',
#   'VBZ',
#   'RB',
#   'VBN',
#   'NN',
#   'VBZ',
#   'PRP$',
#   'NN',
#   '.',
#   'DT',
#   'NNS',
#   'WP',
#   'VBP',
#   'VBG',
#   'RB',
#   'JJ',
#   'TO',
#   'VB',
#   'PRP',
#   'VBP',
#   'RB',
#   'PRP$',
#   'NNS',
#   '.',
#   'DT',
#   'NN',
#   'VBZ',
#   'VBG',
#   'TO',
#   'VB',
#   'DT',
#   'CC',
#   'DT',
#   'CD',
#   'IN',
#   'PRP',
#   'CC',
#   'IN',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   'DT',
#   'JJ',
#   'RP',
#   ',',
#   'DT',
#   'NN',
#   'RB',
#   'MD',
#   '.'],
#  ['CD',
#   ',',
#   'RB',
#   ',',
#   'NN',
#   'VBZ',
#   'JJ',
#   'NN',
#   'PRP',
#   'DT',
#   'NN',
#   '.',
#   'PRP',
#   'VBD',
#   'JJ',
#   'NN',
#   'VB',
#   'DT',
#   'RBS',
#   'JJ',
#   'NN',
#   'TO',
#   'VB',
#   'IN',
#   'PRP',
#   '.',
#   'CC',
#   'VB',
#   'PRP',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'PRP',
#   'VBZ',
#   ',',
#   'PRP',
#   'VBZ',
#   'IN',
#   'PRP',
#   'VBP',
#   'VBN',
#   '.',
#   'IN',
#   'NN',
#   'WDT',
#   'VBZ',
#   'VBN',
#   'TO',
#   'VB',
#   'PRP',
#   'VBZ',
#   'VBN',
#   '.',
#   'VB',
#   'JJ',
#   'NNS',
#   'RB',
#   'JJ',
#   ',',
#   'NN',
#   'MD',
#   'VB',
#   'VBN',
#   'PRP',
#   'DT',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['NNS', 'VBP', 'RB', 'JJ', 'IN', 'NNS', ','],
#  ['IN', 'VBN', 'IN', 'NN', ',', 'JJ', 'NN', ':'],
#  ['CC', 'VBZ', 'JJR', 'JJR', 'IN', 'DT', 'NN', ','],
#  ['IN', 'NNS', 'VBP', 'CC', 'DT', 'NN', 'CC', 'DT', 'NN', '.'],
#  ['RBR', 'DT', 'NN', 'IN', 'DT', 'NNS', ','],
#  ['CC', 'DT', 'JJ', 'NN', ',', 'IN', 'NN', 'IN', 'DT', 'NN', ','],
#  ['IN', 'DT', 'NN', 'JJ', 'IN', 'DT', 'NN', ','],
#  ['WRB', 'DT', 'NN', 'RB', 'NNS', 'VBP', 'JJ', 'MD', '.', 'VB'],
#  ['VB', 'NN', ',', 'CC', 'VBP', 'IN', 'IN', 'DT', 'NN', 'NN'],
#  ['IN', 'NN', 'NNP', 'VBZ', 'JJ', 'NN', ',', 'IN', 'DT', 'NN'],
#  ['NNS', 'DT', 'NN', 'IN', 'DT', 'NN', 'NN', ','],
#  ['NN', '.', 'JJ', 'VBP', 'DT', 'NNS', 'IN', 'PRP$', 'NN'],
#  ['NN', ',', 'IN', 'NN', 'VBN', 'IN', 'NN', ':'],
#  ['VBZ', 'PRP', 'RB', ',', 'CC', 'VB', 'NN', 'RB', ','],
#  ['NNS', 'IN', 'JJ', 'NN', ','],
#  ['TO', 'VB', ',', 'IN', 'JJ', 'NN', ',', 'NN', 'NNP', 'VBZ', 'JJ', 'NN', '.'],
#  ['NN', 'NN', ',', 'CC', 'JJ', 'NN', ',', 'CC', 'DT', 'NN'],
#  ['IN', 'WP', 'VBZ', 'VBN', ',', 'DT', 'NN', 'IN', 'WP', 'MD', 'VB', '.'],
#  ['JJ', 'NN', '.', 'IN', 'JJ', 'MD', 'VB', 'JJ', 'NN'],
#  ['JJ', 'NN', 'VBN', 'IN', 'DT', ',', 'CC', 'PRP', 'IN', 'NN', ':'],
#  ['IN', 'NN', 'CC', 'NNS', 'VBD', 'NNS', 'TO', 'VB', 'VBN'],
#  ['IN', 'NN', 'CC', 'NNS', ',', 'VBP', 'RB', 'DT', 'NN', 'CC', 'JJ'],
#  ['JJ', 'NNS', ',', 'CC', 'NN', 'IN', 'NNS', '.'],
#  ['IN', 'DT', 'JJ', 'NN'],
#  ['DT', 'NNS', 'WP', 'VBD', 'DT', 'NNS'],
#  ['VBD', 'VBN', 'TO', 'VB'],
#  ['CC', 'TO', 'VB', 'DT', 'NNS', '.'],
#  ['DT', 'NNS', 'WP', 'VBD', 'DT', 'NN'],
#  ['VBD', 'VBN', 'RB', 'TO', 'VB', 'IN', 'DT', 'NN', ','],
#  ['CC', 'DT', 'NNS', 'WP', 'VBD', 'IN', 'DT', 'NNS'],
#  ['VBD', 'VBN', ','],
#  ['CC', 'DT', 'NNS', 'WP', 'VBD', 'IN', 'DT', 'NNS', '.'],
#  ['NN', ',', 'IN', 'JJ', 'IN', 'DT', 'NNS', ','],
#  ['VBD', 'VBG', 'NNS', '.'],
#  ['DT', 'NNS', 'VBD', 'VBN', 'RB', 'TO', 'VB'],
#  ['CC', 'VBD', 'VBN', 'RB', '.'],
#  ['DT', 'NNS', ',', 'VBD', 'TO', 'VB', 'VBN', ',', 'VBD', 'JJ', '.'],
#  ['RB', 'PRP', 'VBD', 'RB', 'DT', 'NNS'],
#  ['DT', 'VBD', 'IN', 'DT', 'NNS', ','],
#  ['CC', 'RB', 'DT', 'NN', 'IN', 'VBD', 'IN', 'PRP$', 'NNS', ','],
#  ['IN', 'DT', 'JJ', 'JJ', 'NN', 'IN', 'DT', 'NN', 'NNS'],
#  ['VBN', 'TO', 'VB', 'IN', 'PRP$', 'NN', '.'],
#  ['DT', 'NN', 'VBD', 'RB', 'IN', 'NN', ','],
#  ['CC', 'DT', 'NNS', 'VBD', 'NN', ','],
#  ['IN', 'NNS', ',', 'IN', 'NNS', 'CC', 'NN', '.'],
#  ['IN', 'NN', ',', 'NN', 'CC', 'NN', ','],
#  ['DT', 'JJ', 'NNS', 'VBD', 'NN', '.'],
#  ['NN', 'NNS', ',', 'NN', 'NNS', ','],
#  ['NN', 'NNS', ',', 'NNS', ',', 'NNS', ','],
#  ['NN', 'NN', ',', 'NNS', 'VBD', 'NN', '.'],
#  ['PRP', 'VBD', ',', 'DT', 'JJ', 'NN', ','],
#  ['IN', 'NN', '.'],
#  ['DT', 'NNS', 'VBP', ',', 'PRP$', 'NNS', 'VBP', 'JJ', ','],
#  ['PRP', 'VBP', 'RB', 'JJR', 'VB', 'NN'],
#  ['IN', 'DT', 'NN', 'IN', 'NN', ':'],
#  ['VB', 'NN', 'DT', 'JJ', 'NN', 'RB', '.'],
#  ['NN', '.', 'VBZ', 'DT', 'NN', 'IN', 'NN', ',', 'NNP', 'NN', ','],
#  ['CC', 'NN', 'RB', 'NN', ':'],
#  ['PRP', 'VBZ', 'PRP', 'VBP', 'IN', 'DT', 'NN', ','],
#  ['CC', 'NN', 'RB', 'IN', 'PRP$', 'NN', '.'],
#  ['DT', 'NN', 'NN', 'VBZ', 'JJ'],
#  ['IN', 'DT', 'JJ', 'NN', '.'],
#  ['NN', 'IN', 'PRP$', 'NN', 'NNS', ','],
#  ['DT', 'JJ', 'NN', 'NNS', 'RB', '.'],
#  ['CC', 'VB', 'VBP', 'VBN', 'TO', 'VB'],
#  ['IN', 'JJ', 'NN', ','],
#  ['CC', 'VB', 'DT', 'NNS', 'VBP', 'RP'],
#  ['IN', 'VBN', 'NN', 'VBZ', 'IN', '.'],
#  ['CC', 'RB', 'DT', 'NN', 'VBZ', 'VBN', ','],
#  ['DT', 'NN', 'NN', 'NN', ','],
#  ['CC', 'IN', 'DT', 'RB', 'JJ'],
#  ['JJ', 'VBP', 'NN', 'VBZ', 'NN', '.'],
#  ['RB', 'RB', 'VBZ', 'DT', 'NN'],
#  ['IN', 'CD', 'IN', 'DT', 'NN', ','],
#  ['VB', 'NN', 'RB', 'VBZ', 'TO', 'PRP'],
#  ['WP', 'VBZ', 'PRP$', 'NN', 'IN', 'NN', ',', 'NN'],
#  ['NNS', 'WP', 'VBZ', 'PRP$', 'NN', 'TO', 'VB', ','],
#  ['CC', 'VBG', 'NN', 'IN', 'NN', ','],
#  ['NNS', 'PRP', 'IN', 'NN', 'NN', ','],
#  ['DT', 'NN', 'MD', 'VB', '.', 'VB'],
#  ['RB', 'NNS', 'VBP', 'WRB', 'PRP$', 'JJ', 'NNS', '.'],
#  ['NN',
#   'VBP',
#   'NN',
#   'RB',
#   'VB',
#   'CC',
#   'VB',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'NN',
#   'NNP',
#   'NN',
#   'NN'],
#  ['CC', 'WRB', 'JJ', 'VBP', 'TO', 'VB', 'PRP', ','],
#  ['PRP', 'VBP', 'JJ', 'VBP', 'NN', 'VBG', 'NNS', '.'],
#  ['NNS', 'VBP', ','],
#  ['PRP', 'VBZ', 'NN', 'IN', 'DT', 'NN', 'IN', 'PRP$', 'NNS', ','],
#  ['DT', 'NN', 'IN', 'PRP$', 'NNS', ','],
#  ['DT', 'NN', 'IN', 'PRP$', 'NN', ','],
#  ['DT', 'NN', 'IN', 'PRP$', 'NNS', '.'],
#  ['NN', 'VBP', 'PDT', 'DT', 'NN'],
#  ['RB', '.'],
#  ['JJ', 'NN', ','],
#  ['DT', 'VBZ', 'JJR', 'PRP', '.'],
#  ['NN', 'VBP', 'IN', 'DT', 'NN'],
#  ['RB', 'RB', 'JJ', 'IN', 'PRP', 'VBP', ','],
#  ['CC', 'TO', 'DT', 'NN', ','],
#  ['DT', 'NNS', 'VBP', 'CC'],
#  ['VB', 'RP', 'IN', 'PRP$', 'NNS', '.'],
#  ['RB', 'PRP', 'VBP', 'IN', 'PRP', ','],
#  ['DT', 'NN', 'IN', 'NN', 'NNS', '.'],
#  ['PRP', 'VBZ', 'PDT', 'DT', 'NN', 'IN', 'PRP$', 'NNS', ','],
#  ['CC', 'DT', 'NN', 'IN', 'PRP$', 'NNS', ','],
#  ['DT', 'NN', 'IN', 'PRP$', 'NN', ','],
#  ['CC', 'DT', 'NN', 'IN', 'PRP$', 'NNS', '.'],
#  ['NNS', 'PRP', 'VBP', 'VBN'],
#  ['WP', 'PRP', 'VBP', 'IN', 'PRP', '.'],
#  ['PRP', 'VBP', 'RB', 'JJ'],
#  ['CC', 'PRP', 'MD', 'VB', 'VB', 'NN'],
#  ['PRP$', 'JJ', 'NN', '.'],
#  ['WRB', 'JJ', 'VBP', 'TO', 'VB', 'PRP', ','],
#  ['PRP', 'VBP', 'PRP', 'RB', 'MD', 'VB', 'JJ', 'NN', '.'],
#  ['PRP', 'VBZ', 'NN', 'IN', 'DT', 'NN', 'IN', 'PRP$', 'NN', ','],
#  ['DT', 'NN', 'IN', 'PRP$', 'NN', ','],
#  ['DT', 'NN', 'IN', 'PRP$', 'NNS', ','],
#  ['DT', 'NN', 'IN', 'PRP$', 'NN', '.'],
#  ['RB', 'PRP', 'VBP'],
#  ['RB', 'WRB', 'PRP$', 'NN', 'NNP', 'VBZ', 'RB', 'VBN', '.'],
#  ['JJ', 'VBP', 'JJ', 'NN', 'NN', 'CC', 'NN', 'IN'],
#  ['CC', 'VB', 'TO', 'VB', 'JJ', 'NN', '.'],
#  ['WRB', 'PRP', 'VBP', 'PRP', 'NN', ','],
#  ['PRP', 'MD', 'TO', 'VB', 'PRP', 'JJ', '.'],
#  ['PRP', 'VBZ', 'NN', 'IN', 'DT', 'NN', 'IN', 'PRP$', 'NNS', ','],
#  ['DT', 'NN', 'IN', 'PRP$', 'NN', ','],
#  ['DT', 'NN', 'IN', 'PRP$', 'NN', ','],
#  ['DT', 'NN', 'IN', 'PRP$', 'NN', '.'],
#  ['NN', 'NN', 'NN', 'VBP', 'PDT', 'DT', 'NN'],
#  ['NN', 'RB', 'JJ', ','],
#  ['NN', 'VBP', 'NN', 'RB', 'VB', '.'],
#  ['NN', 'RB', 'JJ', 'IN', 'NN', ','],
#  ['NN', 'NN', 'RB', 'VBP', '.'],
#  ['NN', 'VBZ', 'NN', ','],
#  ['RB', 'WRB', 'PRP', 'VBZ', 'PRP', 'VBZ', '.'],
#  ['RB', 'NN', 'IN', 'NNS', ','],
#  ['NNS', ','],
#  ['RB', 'NNS', 'VBP', 'TO', 'VB', 'JJ', ','],
#  ['IN', 'NNS', 'TO', 'VB', 'PRP', '.'],
#  ['WRB',
#   'MD',
#   'NN',
#   'CC',
#   'NN',
#   'RB',
#   'VB',
#   'JJ',
#   'RB',
#   'WRB',
#   'VBD',
#   'RP',
#   'IN',
#   'NN',
#   'JJ',
#   '.'],
#  ['NN', 'RB', 'RB', 'DT', 'RB', 'JJ', 'NNS', 'VBP', 'CC', 'VBP', ','],
#  ['NN', 'PRP', 'DT', 'VBP', 'VBZ', 'JJ', ','],
#  ['CC', 'PRP', 'VBP', 'VBN', 'IN', 'NN', 'VBZ', 'JJ', ','],
#  ['RB', 'DT', 'IN', 'PRP', 'RB', 'VBP', 'RP', ','],
#  ['PRP', 'MD', 'RB', 'VB', 'PRP', 'JJ'],
#  ['CC', 'PRP', 'MD', 'RB', 'VB', '.'],
#  ['DT', 'JJ', 'NN', 'VBZ', 'TO', 'VB', 'NNS', ','],
#  ['IN', 'RB', 'VBG', 'JJ', ','],
#  ['IN', 'VBG', 'PRP', ','],
#  ['IN', 'VBG', 'JJ'],
#  ['CC', 'VB', 'NN', 'IN', 'PRP', 'VBZ', '.'],
#  ['NN', 'RB', 'VBG', 'VB', 'RP', 'IN', 'PRP$', 'NNS', ','],
#  ['NN', 'VBG', 'NNS', 'VBP', 'PRP', 'NN', 'PRP', 'RB', ','],
#  ['DT', 'NN', 'IN', 'PRP', 'VBP', 'IN', 'PRP$', 'NN', 'WDT', 'VBZ', 'JJ', ','],
#  ['DT',
#   'NN',
#   'VBZ',
#   'RB',
#   'JJ',
#   'IN',
#   'VBG',
#   'NNS',
#   'PRP',
#   'VBZ',
#   'DT',
#   'NN',
#   'CC',
#   'NN',
#   'NNS',
#   'RB',
#   ',',
#   'JJ',
#   'NN',
#   ',',
#   'NN',
#   'CC',
#   'RB',
#   'VBG',
#   'JJ',
#   'RB',
#   'DT',
#   'NN',
#   'WP',
#   'PRP',
#   'VBP',
#   'CC',
#   'WRB',
#   'JJ',
#   'PRP',
#   'VBP',
#   '.'],
#  ['NN', 'VBP', 'NN', 'NN', ',', 'CC', 'VB', 'PRP', '.'],
#  ['IN', 'EX', 'VBP', 'JJR', 'NNS', 'RB'],
#  ['IN', 'WRB', 'NN', 'VBD', 'DT', 'NN', ','],
#  ['NN', 'MD', 'VB', 'NNS', 'VB'],
#  ['WDT', 'VBP', 'VBG', ','],
#  ['WP', 'VBD', 'DT', 'JJ', 'TO', 'VB', 'PRP', '.'],
#  ['VBZ', 'PRP', 'RB', 'DT', 'NN'],
#  ['IN', 'PRP', 'VBP', 'PRP', 'DT', 'NN', '.'],
#  ['PRP', 'VBZ', 'JJ', 'TO', 'VB'],
#  ['DT', 'NN', ','],
#  ['DT', 'NN', 'JJ', 'IN', 'NNS'],
#  ['VBN', '.'],
#  ['NNS', 'VBG', 'IN', 'DT', 'NN'],
#  ['JJ', ','],
#  ['VBG', 'JJ', 'NNS', '.'],
#  ['VB', 'DT', 'TO', 'DT', 'NN', ':'],
#  ['DT', 'IN', 'DT', 'NNS', 'VBD', 'RP'],
#  ['IN', 'JJ', 'NNS', '.'],
#  ['NN', 'VBP', 'PRP$', 'JJS', 'IN', 'DT', 'NN', 'NN', ','],
#  ['WRB', 'DT', 'JJ', 'NNS', 'VBP', 'PRP$', 'NNS', 'TO', 'VB', ','],
#  ['WRB', 'DT', 'NNS', 'NN', ',', 'CC', 'DT', 'NNS', 'VBP', ','],
#  ['CC', 'DT', 'NN', 'NNS', 'NN', 'CC', 'NN', ':'],
#  ['IN', 'PRP$', 'NN', 'JJ', 'NN', 'MD', 'VB'],
#  ['DT', 'NN', 'IN', 'DT', 'NNS', 'IN', 'NN', '.'],
#  ['RB', 'JJ', 'VBP', 'IN', 'PRP$', 'NN', 'JJ', ','],
#  ['IN', 'DT', 'JJ', 'NN', 'IN', 'DT', 'NN', 'NN', ':'],
#  ['IN', 'DT', 'NN', 'NN', 'VB', 'PRP$', 'NN', 'NN', ','],
#  ['CC', 'NN', 'IN', 'DT', 'NN', 'IN', 'NN', 'NN', ':'],
#  ['IN', 'JJ', 'NN', 'TO', 'VB', 'IN', 'DT', 'JJ', 'NN', ','],
#  ['CC', 'NN', 'IN', 'DT', 'NN', 'IN', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['RB', 'JJ', 'NN', 'IN', 'DT', 'NN', 'NN', ','],
#  ['IN', 'DT', 'JJ', 'NN', 'NN', 'NN', 'CC', 'NN', ':'],
#  ['JJ', 'VBP', 'RP', 'DT', 'NN', 'WRB', 'DT', 'NNS', 'NN', ','],
#  ['CC', 'DT', 'JJ', 'JJ', 'NN', 'RB', 'VBZ', ':'],
#  ['IN', ',', 'NN', 'TO', 'PRP', 'VBZ', 'DT', 'NN'],
#  ['IN', 'DT', 'JJ', 'CC', 'JJ', 'NN', '.'],
#  ['NN', 'VBP', 'DT', 'NN', 'WRB', 'DT', 'NNS', 'VBP', ','],
#  ['IN', 'DT', 'NNS', 'NN', 'IN', 'DT', 'NN', 'NN', ':'],
#  ['IN', 'NN', 'MD', 'RB', 'VB', 'IN', 'PRP$', 'NN', 'CC', 'NN', ','],
#  ['IN', 'DT', 'NN', 'VB', 'RB', 'RB', 'JJ', 'CC', 'JJ', ','],
#  ['WRB', 'NN', 'VBZ', 'RB', 'JJ', 'NNS', ','],
#  ['CC', 'NNS', 'DT', 'JJ', 'NN', 'IN', 'NNS', '.'],
#  ['RB', 'VB', 'TO', 'PRP', 'IN', 'PRP$', 'NNS', 'TO', 'VB'],
#  ['DT', 'NN', 'IN', 'DT', 'NNS', 'RB', 'JJ', '.'],
#  ['CC', 'NN', 'RB', 'MD', 'VB', 'IN', 'DT', 'NNS', 'VBP', 'VBP'],
#  ['CC', 'NN', ',', 'IN', 'PRP$', 'NN', 'IN', ','],
#  ['PRP$', 'NN', 'JJ', ',', 'JJ', 'NN', 'CC', 'NN', ','],
#  ['CC', 'NN', 'IN', 'PRP$', 'JJ', 'NN', '.'],
#  ['NN', ',', 'NN', 'NN', 'RB', 'DT', 'NN', 'WRB', 'NN', 'NN', ','],
#  ['JJS', 'TO', 'VB', 'NNS', 'DT', 'NN', 'NN', 'VBP', ','],
#  ['WRB', 'JJ', 'NNS', 'IN', 'VBG', 'NNS'],
#  ['DT', 'JJ', 'NN', 'IN', 'PRP$', 'NNS', ','],
#  ['WRB', 'JJ', 'NN', 'VBD', 'JJ', 'CC', 'JJ'],
#  ['JJ', 'JJ', 'NN', 'NN', ','],
#  ['NN', 'CC', 'VBD', 'DT', 'NN', 'IN', 'DT', 'NN', 'NN', '.'],
#  ['RB', 'MD', 'VB', 'RB', 'IN', 'PRP$', 'NN', 'NN'],
#  ['DT', 'NNS', 'RB', 'VBP', 'VBN', 'IN', 'NN', 'RB', ':'],
#  ['PRP$', 'NN', 'IN', 'DT', 'NN', 'NN', 'NN', ','],
#  ['DT', 'VBG', 'NNS', 'IN', 'DT', 'NN', 'NN', ','],
#  ['CC', 'RB', 'JJ', 'NN', ':', 'IN', 'NN', 'VBP', 'TO', 'VB'],
#  ['DT', 'JJ', 'NN', 'IN', 'DT', 'NN', 'IN', 'DT', 'JJ', '.'],
#  ['``', 'WP', 'VBZ', 'NN', '.', ':', ':', 'NN', 'MD', 'VB'],
#  ['DT', 'WDT', 'NN', 'VBZ', ',', 'RB', 'RB', ':', ':'],
#  ['IN', 'PRP$', 'NN', 'NN', 'VBZ', 'VBN'],
#  ['TO', 'DT', 'NN', 'IN', 'PRP$', 'JJ', '.'],
#  ['``', "''", 'NN', 'TO', 'VB', 'CC', 'VB', 'JJ', 'NN'],
#  ['IN', 'RB', 'VBN', 'NN', 'IN', 'NN', 'TO', 'NN'],
#  ['IN', 'PRP$', 'NNS', ',', 'IN', 'IN', 'DT', 'NN'],
#  ['IN', 'DT', 'NNS', 'POS', 'NN', 'TO', 'VB', ','],
#  ['``', 'RB', 'IN', 'NN', 'IN', 'PRP', 'VBP', 'VBN'],
#  ['NN', ',', 'CC', 'NN', ',', 'CC', 'NN', ',', 'CC', 'NN', ','],
#  ['IN', 'CC', 'IN', 'PRP$', 'JJ', 'MD', 'VB'],
#  ['TO', 'PRP$', 'NN', 'CC', 'NN', '.'],
#  ['``', "''", 'NN', 'TO', 'VB', 'PRP$', 'NNS', 'JJ'],
#  ['IN', 'PRP$', 'NNS', 'VBP', 'CC', 'VBP', ','],
#  ['WRB', 'DT', 'NN', 'NNS', 'VBP', 'JJ', ',', ':', ':'],
#  ['PRP', 'VBP', 'VBG', 'NN', 'NN', 'VBP', '.'],
#  ['``', "''", 'NN', 'TO', 'VB', 'IN', 'JJ', 'JJ'],
#  ['IN', 'DT', 'JJ', 'NN', 'IN', 'PRP$', 'NN'],
#  ['NNS', 'TO', 'DT', 'JJ', 'NNS', 'WDT', 'VBP'],
#  ['VBG', 'IN', 'PRP$', 'NN', ':'],
#  ['``', "''", 'NN', 'TO', 'VB', 'DT', 'NN', 'IN', 'NN'],
#  ['VB', 'IN', 'NN', 'DT', 'NN'],
#  ['RBR', 'IN', 'VB', 'PRP$', 'NN', 'MD'],
#  ['IN', 'DT', 'NNS', 'IN', 'JJ', '.'],
#  ['``', 'NN', 'NN', ':', ':', 'DT', 'NN'],
#  ['IN', 'DT', 'NNS', ',', 'WDT', 'VBP'],
#  ['NN', 'TO', 'NN', 'IN', 'DT', 'NN'],
#  ['IN', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['RB', ',', 'VBP', 'PRP', 'PRP$', 'NN', 'IN', 'DT', 'NN', '.'],
#  ['VB', 'PRP', 'VB'],
#  ['DT', 'NN', 'NN', ',', 'JJ', 'NN', 'CC', 'DT', 'NN', ','],
#  ['DT', 'NN', 'CC', 'DT', 'NN', ','],
#  ['NN', 'NNS', 'CC', 'DT', 'NN', 'NN', ','],
#  ['NNS', 'TO', 'VB', 'JJ', 'VBG', '.', 'DT', ',', 'DT', '.', 'RB'],
#  ['WRB', 'MD', 'PRP', 'VB', 'PRP', 'DT', 'NN', '.'],
#  ['NN', 'NN', '.'],
#  ['VB', 'PRP$', 'NN', '.'],
#  ['RB', '.', 'JJ', '.', 'RB', 'VBZ', 'DT', 'NN'],
#  ['TO', 'VB', 'PRP', 'CC', 'JJ'],
#  ['TO', 'VB', 'NNS', 'CC', 'VB', 'RB', 'NNS'],
#  ['CC', 'VB', 'WDT', 'PRP', 'VBP', 'PRP', '.'],
#  ['MD', 'PRP', 'VB', 'PRP', '.'],
#  ['PRP', 'VBZ', 'VBN'],
#  ['TO', 'VB', 'VB', 'PRP$', 'NNS', 'IN', 'DT', 'NN'],
#  ['CC', 'NN', 'IN', 'NN', '.'],
#  ['PRP', 'VBP', 'JJ', 'NN', 'IN', 'DT', 'NN', '.'],
#  ['JJ', 'NN', 'PRP', 'VBP', 'JJ', 'JJ', '.'],
#  ['WRB', 'IN', 'DT', 'NN', 'VBZ', 'NNS'],
#  ['JJ', 'CC', 'JJ', ',', 'CC', 'RB', 'DT', 'JJ', 'NN', '.'],
#  ['PRP', 'VBZ', 'JJ', ',', 'JJ', ',', 'NN'],
#  ['IN', 'NN', 'CC', 'NNS', 'IN', 'DT', 'NN', '.'],
#  ['VB', 'PRP', ',', 'JJ', 'NN', 'PRP', 'IN', 'PRP', '.'],
#  ['RB', 'PRP$', 'NN', ',', 'IN', 'PRP', ',', 'VBZ', 'JJ', '.'],
#  ['NNS', 'VBP', 'DT', 'NN', 'IN', 'DT', '.'],
#  ['NN', 'RB', ',', 'RB', ',', 'IN', 'IN', 'DT', 'NN', '.'],
#  ['RB', ',', 'WP', 'VBP', 'PRP', 'VB', 'IN', 'DT', '.'],
#  ['VBN', 'IN', 'NN', 'TO', 'VB'],
#  ['CC', 'IN', 'JJ', 'NNS', 'RB', 'VB', 'RB', ','],
#  ['IN', 'NN', ',', 'NN', '.'],
#  ['DT', 'NN', 'NN', ',', 'RB', 'PRP', 'VBP', '.'],
#  ['PRP', 'MD', 'VB', ',', 'PRP', 'MD', 'VB', ','],
#  ['PRP', 'MD', 'VB', ',', 'NN', ',', 'NN', '.'],
#  ['PRP', 'VBZ', ',', 'EX', 'VBZ', 'NN', 'JJ', 'IN', 'PRP', '.'],
#  ['PRP', 'VBP', 'DT', 'NN', ',', 'VB', 'DT', 'NN', '.'],
#  ['PRP', 'VBP', 'DT', 'NN', ',', 'VBP', 'DT', 'NN', '.'],
#  ['PRP$', 'NN', ',', 'VB', 'PRP$', 'JJ', 'NN', '.'],
#  ['MD', 'PRP', 'VB', 'PRP', ',', 'VBZ', 'PRP', ',', 'VBZ', 'PRP', '.'],
#  ['DT', 'NN', 'WP', 'VBZ', 'PRP$', 'JJ', 'NN', ','],
#  ['CC', ',', 'VBG', ',', 'DT', 'PRP$', 'NN', 'NNS', ','],
#  ['DT', 'NN', 'IN', 'DT', 'NN', 'NN', ','],
#  ['CD', 'NN', 'JJ', 'NNS', 'CC', 'NNS', ':'],
#  ['IN', 'RB', 'RB', 'VBZ', 'DT', 'NN', ','],
#  ['CC', 'VB', 'MD', 'RB', 'VB', 'PRP', 'NN', ','],
#  ['PRP$', 'NN', 'VBZ', 'VBN', 'DT', 'NN', 'IN', 'NN'],
#  ['IN', 'RB', 'VBD', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['DT', 'NN', 'WP', 'VBZ', 'PRP$', 'NN', 'NN', ','],
#  ['POS', 'JJ', 'JJ', 'NNS', 'WP', 'VBP', 'CC', 'VBP', ','],
#  ['CC', 'RB', 'VBZ', 'DT', 'NN', 'NN', ','],
#  ['WP', 'IN', 'PRP$', 'NN', 'VB', 'JJ', 'NN', ':', 'CC'],
#  ['VBN', 'RB', 'IN', 'PRP$', 'NNS', 'TO', 'VB'],
#  ['DT', 'NNS', 'IN', 'NN', 'IN', 'PRP', 'VB', ',', 'VB'],
#  ['VBZ', 'VBN', 'IN', 'JJ', 'NN', 'IN', 'NN'],
#  ['VBD', 'VBN', 'IN', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['DT', 'NN', 'WP', 'VBZ', 'PRP$', 'NN', ','],
#  ['IN', 'TO', 'PRP$', 'NN', 'PRP$', 'NN', 'PRP', 'VBZ', ','],
#  ['RB', 'VBZ', 'DT', 'JJ', 'NN', 'NNS', 'CC', 'NN', ','],
#  ['VBG', 'DT', 'NN', 'NN', 'PRP', 'VBZ', ':'],
#  ['IN', 'DT', 'NN', 'CC', 'PRP$', 'NN', 'NN', ','],
#  ['TO', 'VB', 'DT', 'NN', 'WDT', 'VBZ', 'IN', 'PRP', ','],
#  ['NNS', 'JJ', 'NN', 'IN', 'NN', 'DT', 'NN'],
#  ['VBN', 'IN', 'JJ', 'NN', 'IN', 'NN', '.'],
#  ['DT', 'JJ', 'NN', 'VBZ', 'IN', 'NN', ','],
#  ['CC', 'DT', 'NN', ',', 'PRP$', 'NN', ',', 'NN', ','],
#  ['TO', 'CC', 'VB', 'RB', 'JJ', 'NN', ':'],
#  ['VB', 'PRP', 'RB', 'VBZ', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['RB', 'JJ', 'TO', 'DT', 'NN', 'CC', 'MD', ','],
#  ['IN', 'DT', 'NN', 'CC', 'NN', 'IN', 'DT', 'RB', 'RB'],
#  ['VBN', 'IN', 'PRP$', 'NNS', 'CC', 'NN', 'NN', ':'],
#  ['RB', 'VBZ', 'DT', 'JJ', 'NN', 'IN', 'NN', '.'],
#  ['IN', 'PRP$', 'JJ', 'NN', 'VBZ', 'RB', 'VBN'],
#  ['IN', 'NN', ',', 'CC', 'NN', ',', 'CC', 'NN', 'NN', ','],
#  ['RB', 'DT', 'RB', 'MD', 'VB', 'DT', 'JJ', 'JJ', 'NN', ':'],
#  ['TO', 'VB', 'DT', 'NN', 'NN', 'IN', 'NN', '.'],
#  ['``', 'WP', 'VBZ', 'NN', '.', ':', ':', 'NN', 'MD', 'VB'],
#  ['DT', 'WDT', 'NN', 'VBZ', ',', 'RB', 'RB', ':', ':'],
#  ['IN', 'PRP$', 'NN', 'NN', 'VBZ', 'VBN'],
#  ['TO', 'DT', 'NN', 'IN', 'PRP$', 'JJ', '.'],
#  ['``', "''", 'NN', 'TO', 'VB', 'CC', 'VB', 'JJ', 'NN'],
#  ['IN', 'RB', 'VBN', 'NN', 'IN', 'NN', 'TO', 'NN'],
#  ['IN', 'PRP$', 'NNS', ',', 'IN', 'IN', 'DT', 'NN'],
#  ['IN', 'DT', 'NNS', 'POS', 'NN', 'TO', 'VB', ','],
#  ['``', 'RB', 'IN', 'NN', 'IN', 'PRP', 'VBP', 'VBN'],
#  ['NN', ',', 'CC', 'NN', ',', 'CC', 'NN', ',', 'CC', 'NN', ','],
#  ['IN', 'CC', 'IN', 'PRP$', 'JJ', 'MD', 'VB'],
#  ['TO', 'PRP$', 'NN', 'CC', 'NN', '.'],
#  ['``', "''", 'NN', 'TO', 'VB', 'PRP$', 'NNS', 'JJ'],
#  ['IN', 'PRP$', 'NNS', 'VBP', 'CC', 'VBP', ','],
#  ['WRB', 'DT', 'NN', 'NNS', 'VBP', 'JJ', ',', ':', ':'],
#  ['PRP', 'VBP', 'VBG', 'NN', 'NN', 'VBP', '.'],
#  ['``', "''", 'NN', 'TO', 'VB', 'IN', 'JJ', 'JJ'],
#  ['IN', 'DT', 'JJ', 'NN', 'IN', 'PRP$', 'NN'],
#  ['NNS', 'TO', 'DT', 'JJ', 'NNS', 'WDT', 'VBP'],
#  ['VBG', 'IN', 'PRP$', 'NN', ':'],
#  ['``', "''", 'NN', 'TO', 'VB', 'DT', 'NN', 'IN', 'NN'],
#  ['VB', 'IN', 'NN', 'DT', 'NN'],
#  ['RBR', 'IN', 'VB', 'PRP$', 'NN', 'MD'],
#  ['IN', 'DT', 'NNS', 'IN', 'JJ', '.'],
#  ['``', 'NN', 'NN', ':', ':', 'DT', 'NN'],
#  ['IN', 'DT', 'NNS', ',', 'WDT', 'VBP'],
#  ['NN', 'TO', 'NN', 'IN', 'DT', 'NN'],
#  ['IN', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['IN', 'DT', 'NN', 'IN', 'JJ', 'NN'],
#  ['NNS', 'IN', 'JJ', 'NNS', 'VBP'],
#  ['TO', 'VB', 'VB', 'DT', 'NN', 'VB', 'VBN', '.'],
#  ['CC', 'RB', 'IN', 'DT', 'NN', 'NNS'],
#  ['DT', 'JJ', 'NN', 'IN', 'DT', 'NNS', ','],
#  ['IN', 'NNS', 'RB', 'CC', 'VB', 'NNS', '.'],
#  ['NN',
#   'VBD',
#   ',',
#   'PRP',
#   'VBZ',
#   'VBN',
#   ',',
#   'VBP',
#   'IN',
#   'NN',
#   'PRP',
#   'VBP',
#   ','],
#  ['NNS', 'VBP', 'JJ', 'NNS', 'VBP', 'NN', ','],
#  ['CC', 'VB', 'DT', 'NNS', 'TO', 'DT', 'NN', '.'],
#  ['JJ', 'NN', '.', 'NN', '.', 'NN', 'VBZ', 'DT', 'NN', 'NN', ':'],
#  ['DT', 'NN', 'VBZ', 'IN', 'NNS', 'IN', 'NN', '.'],
#  ['JJ', 'NN', 'PRP$', 'JJ', 'NN', '.'],
#  ['NN', 'CC', 'JJR', 'JJ', 'DT', 'JJ', 'NNS', 'VBP', ','],
#  ['DT', 'NN', 'VBZ', 'VBG', 'RB', ','],
#  ['DT', 'VBP', 'DT', 'NN', 'DT', 'JJ', 'NN', 'NN', '.'],
#  ['IN', 'NN', 'TO', 'VB', ',', 'IN', 'NN', 'TO', 'VB', ','],
#  ['DT', 'NNS', 'IN', 'DT', 'VBP', 'MD', 'VB', ','],
#  ['NN', 'NN', 'VBZ', 'TO', 'DT', 'NN', '.'],
#  ['NN', 'VBP', 'NN', 'VBG', 'IN', 'DT', 'NN', 'NN', ','],
#  ['DT', 'JJS', 'PRP', 'VBZ', 'RB', 'VBN', 'TO', 'VB', 'IN', 'CD'],
#  ['CC', 'VB', 'VBN', 'PRP', 'MD', 'VB', 'RB', 'TO', 'VB', 'PRP', '.'],
#  ['WDT',
#   'MD',
#   'VB',
#   'JJ',
#   'VB',
#   'JJ',
#   ',',
#   'PRP',
#   'VBP',
#   ',',
#   'CC',
#   'IN',
#   'DT',
#   'NN'],
#  ['RB', 'DT', 'NN', 'NNP', 'NN', 'NN', 'VBZ', 'NN'],
#  ['CC', 'VBZ', 'IN', 'NN', 'RB', '.', 'PRP', 'VBD', 'RB', 'VBN', '.'],
#  ['IN', 'PRP', 'CC', 'WP', 'PRP', 'VBP', '.', 'PRP'],
#  ['CC', 'DT', 'NN', 'PRP', 'VBP', '.', 'DT', 'JJ', 'NN'],
#  ['PRP', 'NN', 'NN', 'IN', ',', 'DT', 'JJ', 'NN'],
#  ['IN', 'PRP', 'CC', 'PRP', 'CC', 'DT', 'JJS', 'IN', 'NN', '.'],
#  ['PRP', 'VBZ', 'JJ', 'RB', 'JJ', 'NN', 'CC', 'DT', 'NN'],
#  ['VBZ', 'IN', 'IN', 'DT', 'JJ', 'NNS', 'IN', 'NN', '.'],
#  ['DT', 'NNS', 'MD', 'RB', 'VB', 'IN', 'NN', '.'],
#  ['CC', 'MD', 'PRP$', 'NN', '.', 'CC', 'MD', 'DT', 'NN', '.'],
#  ['PRP', 'VBP', 'VBN', 'CC', 'RB', 'RB'],
#  ['PRP', 'VBP', 'RB', 'VB', 'CD', 'DT', '.', 'NN', 'VBP', 'VBG'],
#  ['RB', 'JJ', 'TO', 'VB', 'DT', 'NN', ',', 'VBP', 'VBP', 'PRP'],
#  ['RB',
#   'IN',
#   'JJ',
#   'VBP',
#   'NN',
#   'IN',
#   'TO',
#   'VB',
#   'NN',
#   'PRP',
#   '(',
#   'VB',
#   'VBP',
#   'DT',
#   ')'],
#  ['IN', 'DT', 'NN', 'NNS', 'VBP', 'TO', 'VB', 'VBN'],
#  ['WDT', 'VBZ', 'IN', 'NN', ',', 'WDT', 'VBZ', 'RB'],
#  ['JJ',
#   '.',
#   'VB',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBP',
#   'PRP',
#   'IN',
#   ',',
#   'PRP',
#   'VBP',
#   ','],
#  ['CC', 'VB', 'VBP', 'DT', 'JJ', 'NN', 'NN', 'VBD', 'PRP', 'IN', 'DT', 'NN'],
#  ['IN', 'NN', 'RB', '.', 'VB', 'JJ', 'NN', 'PRP', 'VBP', 'DT', 'NN', '.'],
#  ['CC',
#   'IN',
#   'PRP',
#   'VBZ',
#   'JJ',
#   'JJ',
#   'TO',
#   'VB',
#   'PRP',
#   ',',
#   'RB',
#   'VBP',
#   ',',
#   'VB',
#   'VBP',
#   'JJ'],
#  ['TO',
#   'VB',
#   'PRP',
#   'JJ',
#   'VBP',
#   '.',
#   'IN',
#   'DT',
#   'NN',
#   'VBZ',
#   'CD',
#   'NNS',
#   'RB',
#   ':'],
#  ['DT', 'NN', 'VBZ', 'NN', '.', 'PRP', 'VBP', 'VB', 'IN', 'DT', 'NN', '.'],
#  ['RB', 'IN', 'DT', 'JJ', 'NN', 'IN', 'JJ', 'NN', ','],
#  ['IN', 'VBG', 'NNS', 'RB', 'IN', 'NN', 'TO', 'NN', ':'],
#  ['RB', 'IN', 'PRP$', 'JJ', ',', 'VB', 'NNS', 'MD', 'VB'],
#  ['DT', 'JJ', 'NN', 'IN', 'DT', 'NN', ',', 'WP$', 'NN'],
#  ['VBZ', 'DT', 'JJ', 'NN', ',', 'CC', 'PRP$', 'NN'],
#  ['NN', 'IN', 'NNS', '.', 'IN', 'PRP$', 'NN'],
#  ['NNS', 'JJ', 'NN', ':', 'PRP$', 'JJ', 'NNS', 'NN'],
#  ['DT', 'JJ', 'NN', 'IN', 'JJ', 'NNS', 'NN', '.'],
#  ['JJ',
#   'NN',
#   ',',
#   'JJ',
#   'NNS',
#   ',',
#   'PRP$',
#   'JJ',
#   'NN',
#   '.',
#   'NN',
#   'NNS',
#   'PRP'],
#  ['IN',
#   'JJ',
#   'NNS',
#   '.',
#   'VB',
#   'VB',
#   'PRP',
#   'PRP$',
#   'JJ',
#   ',',
#   'PRP$',
#   'JJ',
#   ','],
#  ['PRP$', 'JJ', 'NNS', 'VBG', 'TO', 'VB', 'JJ', ','],
#  ['DT', 'JJ', 'NN', 'IN', 'PRP$', 'VBG', 'NN', '.'],
#  ['VB', 'DT', ',', 'DT', 'NN', ',', 'NN', 'TO', 'PRP', ','],
#  ['NN', 'VBP', 'PRP$', 'JJ', 'IN', 'DT', 'JJ', 'NN', '.', 'NN'],
#  ['DT', 'NN', 'NN'],
#  ['VBD', 'RB', 'VB', 'NNS', 'CC', 'NN', 'NNS', ','],
#  ['RB', 'PRP$', 'NN', 'VBD', 'DT', 'NN', 'NN'],
#  ['IN', 'DT', 'NN', 'NN', 'NN', ',', 'JJ', 'NN', 'NN', 'NNP', 'NN', 'NN', ','],
#  ['IN', 'DT', 'NN', 'VBG', 'IN', 'JJ', 'NN', '.'],
#  ['CC', 'DT', 'NNS', 'VBD', 'NNS'],
#  ['CC', 'NNS', 'TO', 'VB', 'DT', 'NN', ','],
#  ['CC', 'PRP$', 'NN', 'VBD', '.'],
#  ['IN', 'CD', ',', 'NN', 'VBD', 'RB', 'VBN', 'NN', ','],
#  ['CC', 'DT', 'NN', 'VBD', 'PRP', 'IN', 'DT', 'NN', 'NNS'],
#  ['VBN', 'IN', 'CD', 'IN', 'DT', 'NNS', 'IN', 'NN', '.'],
#  ['NN', 'VBD', 'WP', 'JJ', 'VBD', ':', 'NN', 'VBD', 'DT', 'NN'],
#  ['NN', 'IN', 'NNS', 'CC', 'VBD'],
#  ['IN', 'DT', 'NN', 'NN', '.'],
#  ['NN', 'VBD', 'PRP$', 'NN', 'VBD', 'JJ', '.'],
#  ['JJ', 'VBD', 'NN', 'CC', 'JJ', ',', 'DT', 'JJ', 'NN'],
#  ['WP', 'VBD', 'RB', 'VB', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['NN', 'VBD', 'VBG', 'PRP$', 'VBN', 'NN'],
#  ['IN', 'DT', 'NN', ',', 'PRP$', 'NN', 'NN', '.'],
#  ['NNS', 'RB', ',', 'PRP', 'VBD', 'IN', 'DT', 'NN'],
#  ['VBG', 'IN', 'PRP$', 'JJ', 'NN', '.'],
#  ['RB', 'JJ', ',', 'IN', 'NN', 'MD', 'VB', 'TO', 'VB'],
#  ['DT', 'VBZ', 'JJ', 'NNS', 'VBP'],
#  ['IN', 'NN', ',', 'IN', 'NNS', 'DT', 'NN', 'MD', 'VB'],
#  ['VBG', 'PRP$', 'NNS', 'VBN', '.'],
#  ['NN', 'MD', 'VB', 'RB', 'DT', 'VBZ', 'NN', 'NN'],
#  ['VBZ', 'RB', 'DT', 'NN', 'NNP', 'NN', 'NN', ','],
#  ['IN', 'NN', 'MD', 'VB', 'DT', 'NN', 'NN'],
#  ['IN', 'DT', 'JJ', 'NN', 'IN', 'DT', 'NN', '.'],
#  ['DT', 'NN', 'PRP$', 'NN', 'VBD'],
#  ['IN', 'DT', 'NN'],
#  ['RB', 'IN', 'VBG', 'DT', 'NN', 'TO', 'VB', 'CD', ':', 'NN', ','],
#  ['CC', 'DT', 'NN', 'NN', 'MD', 'RB', 'VB'],
#  ['IN', 'JJ', 'NN', '.'],
#  ['NN', 'VBD', 'PRP$', 'NN', 'NN', 'NN', 'NNS'],
#  ['IN', 'DT', 'NN', 'IN', 'DT', 'NN', '.'],
#  ['IN', 'IN', 'NN', 'NNS', ',', 'IN', 'IN', 'VBG', 'NN', ','],
#  ['IN', 'IN', 'JJ', 'NN', 'CC', 'JJ', 'NN', 'NN', ','],
#  ['IN', 'IN', 'DT', 'NNS', 'IN', 'NN', ',', 'DT', 'NN', 'IN', 'NN', ','],
#  ['IN', 'IN', 'NN', ',', 'NN', ',', 'JJ', 'NNS', ',', 'JJ', 'NNS', ','],
#  ['PRP', 'VBP', 'NNS', '.'],
#  ['IN', 'IN', 'DT', 'JJ', 'NNS'],
#  ['IN', 'JJ', 'NNS', ',', 'IN', 'IN', 'NN', ',', 'IN', 'IN', 'NN', 'NN', ','],
#  ['JJS', 'NN', 'TO', 'VB', 'PRP$', 'NN', ',', 'IN', 'IN', 'JJ', 'NNS', ','],
#  ['NNS', 'VBG', 'IN', 'VBN', 'NNS', ',', 'IN', 'IN', 'NNS', ','],
#  ['IN',
#   'IN',
#   'DT',
#   'NNS',
#   'NNP',
#   'VBP',
#   'TO',
#   'VB',
#   'CC',
#   'DT',
#   'NNS',
#   'VBP',
#   'TO',
#   'VB',
#   ','],
#  ['NN', 'VBZ', 'VBG', 'NNS', ',', 'NN', 'NNS', ','],
#  ['JJ', 'NNS', ',', 'NN', 'VBZ', 'VBG', 'IN', 'PRP$', 'JJ', 'NNS', ','],
#  ['JJ', 'VBN', 'NN', ',', 'VB', 'NN', '.', 'NN', 'IN', 'NN', 'NNS', ','],
#  ['IN', 'DT', 'NN', 'IN', 'NN', 'VBN', 'TO', 'VB', ','],
#  ['IN', 'DT', 'JJ', 'NN', 'CC', 'DT', 'JJ', 'NN', 'VB'],
#  ['DT', 'NN', 'IN', 'DT', 'NN', 'RB', ',', 'IN', 'DT', 'NN'],
#  ['IN', 'DT', 'JJ', 'NNS', 'IN', 'DT', 'NNS'],
#  ['VB', 'DT', 'JJ', 'NNS', 'IN', 'DT', 'NN', ',', 'IN', 'DT', 'JJ', 'NN'],
#  ['IN', 'DT', 'NNS', 'DT', 'NN', 'IN', 'NNS', ','],
#  ['IN', 'NNP', 'VBD', 'RB', 'NNP', 'VBP', 'NNS', 'VB', 'RB', ',', 'NNS'],
#  ['NN', 'PRP', 'VBP', 'IN', 'DT', 'NNS', 'IN', 'NNS', ','],
#  ['DT', 'JJ', 'NN', 'WDT', 'VBZ', 'DT', 'NNS', ','],
#  ['IN', 'PRP$', 'CD', 'NNS', 'CC', 'DT', 'PRP$', 'NNS', ','],
#  ['IN', 'DT', 'PRP$', 'JJ', 'NNS', 'VBN', ',', 'PRP', 'VBP', ','],
#  ['IN', 'PRP$', 'NN', 'VBG', 'IN', 'DT', 'NNS', ','],
#  ['PRP', 'VBP', ',', 'IN', 'PRP$', 'NNS', 'NN', ','],
#  ['IN', 'DT', 'NN', 'VBD', 'TO', 'DT', 'NN', ',', 'PRP', 'VBP', ','],
#  ['IN', 'PRP', 'VBP', 'CC', 'PRP', 'RB', 'VBD'],
#  ['CC', 'DT', 'WDT', 'VBD', 'VBN', 'NN', 'IN', 'DT', 'JJ', 'NN'],
#  ['PRP', 'VBP', 'PRP', 'NN', 'CC', 'PRP', 'VBZ', '.'],
#  ['PRP', 'VBD', 'PRP', 'RP', 'IN', 'JJ', 'NNS'],
#  ['IN', 'WRB', 'DT', 'JJ', 'NN'],
#  ['PRP', 'VBD', 'PRP', 'IN', 'DT', 'NN', 'NN'],
#  ['IN', 'PRP', 'VBD', 'PRP', 'NNP', 'RB', 'VBZ', 'NN'],
#  ['RB', '.', 'MD', 'VB', 'VB', 'VBN', 'VB'],
#  ['CC', 'VBN', 'PRP$', 'NN', 'NN', 'VBP', 'NN', 'NN'],
#  ['PRP', 'MD', 'IN', 'NN', 'VBP', 'VBN', 'DT', 'NN'],
#  ['IN', 'NN', 'NN', 'IN', 'DT', 'NN', 'NN'],
#  ['PRP', 'VBZ', 'CC', 'TO', 'MD'],
#  ['CC', 'JJ', 'IN', 'DT', 'NN'],
#  ['VB', 'RP', 'RB', 'NN', 'NN'],
#  ['CC', 'IN', 'JJ', 'DT', 'RBR', 'VBP', 'VBN', 'VBP'],
#  ['NN', 'VBG', 'RP', 'IN', 'IN', 'DT', 'NN', ',', 'NNS', 'IN', 'NN'],
#  ['RB',
#   'WRB',
#   'PRP',
#   'VBD',
#   'PRP',
#   'VBD',
#   'PRP',
#   'RP',
#   ',',
#   'IN',
#   'NN',
#   ',',
#   'NN'],
#  ['NN', 'VBG', 'RP', 'RB'],
#  ['MD', 'PRP', 'VB', 'DT', 'NN', 'JJ', 'IN', 'PRP$', 'NNS', '.'],
#  ['NN', 'VBG', 'RB', ',', 'JJ', 'NN', 'RP', ',', 'RB', 'VBG', 'RP'],
#  ['NN', 'VBG', 'IN', 'PRP$', 'NN', 'IN', 'NN', ',', 'PRP$', 'JJ', 'NN'],
#  ['JJ', 'NNS', 'IN', 'NN', ',', 'JJ', 'NNS', '.'],
#  ['VB', 'JJ', 'JJ', 'NNS', 'VBP', 'JJ'],
#  ['NN', 'VBG', 'RP', 'IN', 'PDT', 'DT', 'VBD', 'VBN'],
#  ['VB', 'JJ', ',', 'JJ', 'NNS', ',', 'VBP', 'JJ'],
#  ['NN', 'VBG', 'RP', 'IN', 'DT', 'PRP', 'VBD', 'VBN', ','],
#  ['PDT',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NNS',
#   'IN',
#   'PRP',
#   'IN',
#   'JJ',
#   'CC',
#   'JJ',
#   'NNS'],
#  ['NNS', 'IN', 'JJ', 'NNS', ',', 'JJ', 'NNS', 'CC', 'NNS'],
#  ['RB', 'VBN', 'VBG', 'RB', ',', 'PRP$', 'NNS', 'VBP', 'JJ'],
#  ['NN', 'VBG', 'RP', 'DT', 'NN', 'IN', 'DT', 'PRP', 'VBP', 'TO', 'VB'],
#  ['PDT', 'DT', 'NN', 'CC', 'NN', 'PRP', 'VBP'],
#  ['PDT', 'DT', 'NNS', 'IN', 'PRP$', 'NN', 'CC', 'NN'],
#  ['NN', 'VBG', 'RP', 'IN', 'NN', 'IN', 'DT', 'PRP', 'RB', 'VBD'],
#  ['PDT', 'DT', 'JJ', 'NNS', ',', 'PDT', 'DT', 'NNS', 'VBP', 'VBG', 'RB'],
#  ['NN', 'VBG', 'PRP', 'RP', 'RB', 'RB'],
#  ['NN', 'VBG', 'TO', 'VB', 'CC', 'VB', 'CC', 'VB', 'CC', 'VB'],
#  ['NN', 'VBG', 'DT', 'NN'],
#  ['NN', '.'],
#  ['WP',
#   'VBZ',
#   'TO',
#   'VB',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   '.',
#   'PRP',
#   'VBZ',
#   'TO',
#   'VB',
#   'IN',
#   'NNS',
#   ',',
#   'TO',
#   'VB'],
#  ['DT',
#   'JJ',
#   'NNS',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'PRP$',
#   'NN',
#   'NN',
#   ',',
#   'IN',
#   'PRP',
#   'VBP',
#   'PRP',
#   'RB'],
#  ['NN',
#   'IN',
#   'NN',
#   'CC',
#   'NN',
#   'NN',
#   'NN',
#   ',',
#   'NN',
#   'VB',
#   'DT',
#   'NN',
#   'VBG',
#   'IN'],
#  ['PRP$',
#   'NNS',
#   ',',
#   'DT',
#   'NNS',
#   'VBG',
#   'NN',
#   'RB',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'PRP',
#   'TO',
#   '.'],
#  ['RB', 'NN', 'IN', 'VBG', 'NN', 'IN', 'NNS', 'CC', 'JJ', 'NNS', 'VBP'],
#  ['NN',
#   'PRP',
#   'VBP',
#   '.',
#   'WP',
#   'VBZ',
#   'PRP',
#   'VB',
#   'TO',
#   'VB',
#   'JJR',
#   '.',
#   'RB',
#   'DT',
#   'NN',
#   'IN',
#   ':'],
#  ['IN',
#   'NNS',
#   'MD',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   '.',
#   'RB',
#   'JJ',
#   'VBP',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'TO'],
#  ['NN',
#   'CC',
#   'VB',
#   'PRP',
#   ',',
#   'VBZ',
#   'VBP',
#   'VB',
#   '.',
#   'NN',
#   'VBP',
#   'TO',
#   ',',
#   'CC',
#   'PRP',
#   'VBP',
#   'IN',
#   'IN',
#   'PRP',
#   '.',
#   'CC'],
#  ['IN',
#   'JJ',
#   'NN',
#   'PRP',
#   ',',
#   'IN',
#   'NN',
#   'VBP',
#   'PRP',
#   ',',
#   'VB',
#   'RB',
#   'JJ',
#   ',',
#   'RB',
#   'JJ',
#   'IN',
#   'PRP',
#   'TO',
#   'VB',
#   '.'],
#  ['RB',
#   'VBZ',
#   'WP',
#   'PRP',
#   'VBP',
#   'WRB',
#   'PRP',
#   'VBD',
#   'PRP',
#   'VBP',
#   'VB',
#   'DT',
#   'NN'],
#  ['RB', 'JJ', '.']]

# %% [markdown]
# ### 5. Generate random sequences

# %%
def lineGenerator(n, gm, seq):
    # inputs:
    # n: number of lines
    # gm: grammar symbols
    # seq: all sequences of symbols
    
    generated_poem=""
    
    
    # Pick a random number for n line-sequence , meaning a range between 0 and len(seq)-n
    random_sequence = random.randint(0, len(seq)-n)

    
    for sequence in seq[random_sequence:random_sequence+n]:
        generated_line=""
        for symbol in sequence:
            random_word = random.choice(gm[symbol])
            generated_line+=random_word+" "
        
        #twitter character limit - 280
        if (len(generated_poem)+len(generated_line))<=280:
            generated_poem+=generated_line
        else:
            #print('----280 CHARACTERS LIMIT', len(generated_poem+generated_line))
            #print('length without this sentence:', len(generated_poem))
            break
        
    generated_poem = generated_poem.replace(" ,", ",")
    generated_poem = generated_poem.replace(" .", ".")
    generated_poem = generated_poem.replace(" !", "!")
    generated_poem = generated_poem.replace(" ?", "?")
    generated_poem = generated_poem.replace(" ;", ";")
    generated_poem = generated_poem.replace(" :", ":")
    generated_poem = generated_poem.replace(" i ", " I ")
    generated_poem = generated_poem.replace("\'s", "'s")
    generated_poem = generated_poem.replace(" -", "-")
    generated_poem = generated_poem.replace(" 's", "'s")
    generated_poem = generated_poem[:-1]
            
    #if (generated_poem[-1]==",") or "?" or ":" or ";" or "-")):
    if (generated_poem[-1]==",") or (generated_poem[-1]=="-") or (generated_poem[-1]==":") or (generated_poem[-1]==";"):
        generated_poem=generated_poem[:-1]
        generated_poem=generated_poem+"."        

        
    generated_poem = generated_poem.replace("“", "")
    
    
    # transform it into list for capitalization
    sample_list=list(generated_poem)                                           

    


    for index, letter in enumerate(generated_poem):
        if ((letter == "?") or (letter == ".") or (letter == "!")):
            try:
                #generated_poem = generated_poem[:index+2] + generated_poem[index+2:].upper()
                sample_list[:index+2]=sample_list[:index+2].upper()
                generated_poem = ''.join(str(i) for i in sample_list)
                print("index", generated_poem[index+2])
            except:
                pass
    return generated_poem


    
# Example
#directory= 'C:\\Users\\merse\\Desktop\\Commonsensical\\Projects\\May 2021\\Twitter Bot, the revolutionary poet\\4. Development\\Corpus\\'
#all_tokens = analyseAndTokenize(directory)
#grammar_symbols, sequences = grammarSymbolsAndSequences(all_tokens)
#lineGenerator(2,grammar_symbols, sequences)

# %% [markdown]
# ### 6. Generate a poem (directory, number of lines)

# %%
def poem_generator(direct, number_of_lines):
    all_tokens = analyseAndTokenize(direct)
    grammar_symbols, sequences = grammarSymbolsAndSequences(all_tokens)
    
    poem = lineGenerator(number_of_lines,grammar_symbols, sequences).capitalize()
    for index, character in enumerate(poem):
        if (character=="?") or (character==".") or (character=="!"):
            try:
                poem = poem[:index+2] + poem[index+2:].capitalize()
            except:
                pass
        
        if (character=="\\"):
            poem = poem[:index] + poem[index+1:]
    try:
        poem=poem.replace(' i ', " I ")
        poem=poem.replace(" i'm ", " I'm ")
        poem=poem.replace("\\", "")
    except:
        pass
    return poem

# %%
directory= '..\\Corpus\\'
poem_generator(directory,10)
# Out:
# "Bolder hit what united left: fit fell any thee rage — stars but used o'er all bank pierce! Bury sat my image joined rumble? Easy appeared stock and ill-apportioned, all acceptable drooping what began exactly humb'ly those neck since other's."

# %% [markdown]
# ## 7. Twitter Authentication

# %%
CONSUMER_KEY = 'mDgBJy8f4FP511hBId8sPp94a'
CONSUMER_SECRET = '2bEYAtiKj9db2G9GfWzkju2NKjznmrTJAy5RJHJLiDydmT3bEK'
ACCESS_KEY = '1399298847143251969-xfcOHTbvXbQcwiwogIxmhSpHF8SEgM'
ACCESS_SECRET = 'tYlYRHd7y1cHcSYau4dJnhcPIi9XqIMnl8tj1BfX8tfcI'
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_KEY, ACCESS_SECRET)

# %% [markdown]
# ### 8. Make a tweet

# %%
# Create API object
api = tweepy.API(auth)

# Create a tweet
#api.update_status("Hello Tweepy")

api.update_status(poem_generator(directory,random.randint(1,10)))
# Out:
# Status(_api=<tweepy.api.API object at 0x0000019FD854EEB0>, _json={'created_at': 'Wed Jun 02 10:15:52 +0000 2021', 'id': 1400033414586187779, 'id_str': '1400033414586187779', 'text': "Up should accept depress around her despot land both bolts proudly grind dreaded laugh plan right; her mountain's b… https://t.co/qB71HiCILs", 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/qB71HiCILs', 'expanded_url': 'https://twitter.com/i/web/status/1400033414586187779', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">Botshevic</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1399298847143251969, 'id_str': '1399298847143251969', 'name': 'Botshevic', 'screen_name': 'botshevic', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 0, 'listed_count': 0, 'created_at': 'Mon May 31 09:37:08 +0000 2021', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 8, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 6, 2, 10, 15, 52), id=1400033414586187779, id_str='1400033414586187779', text="Up should accept depress around her despot land both bolts proudly grind dreaded laugh plan right; her mountain's b… https://t.co/qB71HiCILs", truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/qB71HiCILs', 'expanded_url': 'https://twitter.com/i/web/status/1400033414586187779', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, source='Botshevic', source_url='https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000019FD854EEB0>, _json={'id': 1399298847143251969, 'id_str': '1399298847143251969', 'name': 'Botshevic', 'screen_name': 'botshevic', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 0, 'listed_count': 0, 'created_at': 'Mon May 31 09:37:08 +0000 2021', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 8, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/st ...

# %% [markdown]
# ### API

# %%
# api key
#mDgBJy8f4FP511hBId8sPp94a

# api secret key
#2bEYAtiKj9db2G9GfWzkju2NKjznmrTJAy5RJHJLiDydmT3bEK

#bearer token
#AAAAAAAAAAAAAAAAAAAAANL4QAEAAAAAEW8xJzSNZJjIPZeVl7tiuRhteGU%3DApSXq3acJeRClj2N4DKA1jV3eRZApZjgjasvR5Unl5SzKwgMHZ

# access token
#1399298847143251969-xfcOHTbvXbQcwiwogIxmhSpHF8SEgM

#access token secret
#tYlYRHd7y1cHcSYau4dJnhcPIi9XqIMnl8tj1BfX8tfcI
